# %%
from datetime import timedelta

import pandas as pd
import numpy as np

from catboost import CatBoostRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import KFold

# %%
data = pd.read_csv('train_dataset_train.csv', sep=';', dtype={'VISIT_MONTH_YEAR': str})

# %%
data['MONTH'] = data['VISIT_MONTH_YEAR'].str.split('.').str.get(0).astype(int)
data['YEAR'] = data['VISIT_MONTH_YEAR'].str.split('.').str.get(1).astype(int)
data.drop('VISIT_MONTH_YEAR', axis=1, inplace=True)
data['CODE_TYPE'] = data['MKB_CODE'].str[0]
data['CODE_CATEGORY'] = data['MKB_CODE'].str[:3]

# %%
data.sort_values(['YEAR', 'MONTH'], inplace=True)

# %%
adres_stat = data.groupby('ADRES')['PATIENT_ID_COUNT'].sum().reset_index()

# %%
adres_stat
# Out:
#                ADRES  PATIENT_ID_COUNT
# 0      Багратионовск            119629
# 1           Балтийск            227475
# 2          Березовка              4254
# 3         Большаково              9069
# 4    Большое Исаково             40875
# ..               ...               ...
# 113        Шоссейное             11847
# 114            Южный              7784
# 115         Янтарный             31022
# 116     Ясная Поляна              3432
# 117            Ясное              4715
#
# [118 rows x 2 columns]

# %%
adres_stat['size'] = 0
adres_stat.loc[adres_stat['PATIENT_ID_COUNT'] > 1000, 'size'] = 1
adres_stat.loc[adres_stat['PATIENT_ID_COUNT'] > 10000, 'size'] = 2
adres_stat.loc[adres_stat['PATIENT_ID_COUNT'] > 100000, 'size'] = 3
adres_stat.loc[adres_stat['PATIENT_ID_COUNT'] > 1000000, 'size'] = 4

# %%
adres_stat.drop('PATIENT_ID_COUNT', axis=1, inplace=True)

# %%
data = data.merge(adres_stat, how='left')

# %%
test = pd.read_csv('test_dataset_test.csv', sep=';', dtype={'VISIT_MONTH_YEAR': str})
test['MONTH'] = test['VISIT_MONTH_YEAR'].str.split('.').str.get(0).astype(int)
test['YEAR'] = test['VISIT_MONTH_YEAR'].str.split('.').str.get(1).astype(int)
test.drop('VISIT_MONTH_YEAR', axis=1, inplace=True)
test['CODE_TYPE'] = test['MKB_CODE'].str[0]
test['CODE_CATEGORY'] = test['MKB_CODE'].str[:3]
test = test.merge(adres_stat, how='left')

# %%
data[['YEAR', 'MONTH']].iloc[0], data[['YEAR', 'MONTH']].iloc[-1]
# Out:
# (YEAR     18
#  MONTH     1
#  Name: 0, dtype: int64,
#  YEAR     22
#  MONTH     3
#  Name: 2212392, dtype: int64)

# %%
test[['YEAR', 'MONTH']].iloc[0], test[['YEAR', 'MONTH']].iloc[-1]
# Out:
# (YEAR     22
#  MONTH     4
#  Name: 0, dtype: int64,
#  YEAR     22
#  MONTH     4
#  Name: 39372, dtype: int64)

# %%
data['DAY'] = 1
test['DAY'] = 1

# %%
data['YEAR'] = 2000+data['YEAR']
test['YEAR'] = 2000+test['YEAR']

# %%
data['DATE'] = pd.to_datetime(data[['YEAR', 'MONTH', 'DAY']])
test['DATE'] = pd.to_datetime(test[['YEAR', 'MONTH', 'DAY']])

# %%
data['PREV_MONTH'] = (data['DATE'] - timedelta(days=28)).dt.to_period('M')
test['PREV_MONTH'] = (test['DATE'] - timedelta(days=28)).dt.to_period('M')

# %%
data['PREV_2_MONTH'] = (data['DATE'] - timedelta(days=58)).dt.to_period('M')
test['PREV_2_MONTH'] = (test['DATE'] - timedelta(days=58)).dt.to_period('M')

# %%
data['PREV_YEAR'] = (data['DATE'] - timedelta(days=365)).dt.to_period('M')
test['PREV_YEAR'] = (test['DATE'] - timedelta(days=365)).dt.to_period('M')

# %%
data['PREV_11_MONTH'] = (data['DATE'] - timedelta(days=365-28)).dt.to_period('M')
test['PREV_11_MONTH'] = (test['DATE'] - timedelta(days=365-28)).dt.to_period('M')

# %%
data['PREV_13_MONTH'] = (data['DATE'] - timedelta(days=365+28)).dt.to_period('M')
test['PREV_13_MONTH'] = (test['DATE'] - timedelta(days=365+28)).dt.to_period('M')

# %%
data['DATE'] = data['DATE'].dt.to_period('M')
test['DATE'] = test['DATE'].dt.to_period('M')

# %%
data
# Out:
#          PATIENT_SEX MKB_CODE                     ADRES AGE_CATEGORY  \
# 0                  0    A02.0               Калининград     children
# 1                  0    A02.0               Калининград      elderly
# 2                  0    A02.0               Калининград        young
# 3                  0    A02.0  СТ Искра ул. Тюльпановая     children
# 4                  0      A02               Калининград     children
# ...              ...      ...                       ...          ...
# 2212388            1    Z96.6               Калининград    middleage
# 2212389            1    Z96.6                Пионерский    middleage
# 2212390            1    Z98.8               Калининград     children
# 2212391            1    Z98.8                    Озерск      elderly
# 2212392            1    Z98.8                Пионерский      elderly
#
#          PATIENT_ID_COUNT  MONTH  YEAR CODE_TYPE CODE_CATEGORY  size  DAY  \
# 0                       3      1  2018         A           A02     4    1
# 1                       1      1  2018         A           A02     4    1
# 2                       2      1  2018         A           A02     4    1
# 3                       1      1  2018         A           A02     1    1
# 4                       1      1  2018         A           A02     4    1
# ...                   ...    ...   ...       ...           ...   ...  ...
# 2212388                 1      3  2022         Z           Z96     4    1
# 2212389                 1      3  2022         Z           Z96     3    1
# 2212390                 1      3  2022         Z           Z98     4    1
# 2212391                 1      3  2022         Z           Z98     2    1
# 2212392                 1      3  2022         Z           Z98     3    1
#
#             DATE PREV_MONTH PREV_2_MONTH PREV_YEAR PREV_11_MONTH PREV_13_MONTH
# 0        2018-01    2017-12      2017-11   2017-01       2017-01       2016-12
# 1        2018-01    2017-12      2017-11   2017-01       2017-01       2016-12
# 2        2018-01    2017-12      2017-11   2017-01       2017-01       2016-12
# 3        2018-01    2017-12      2017-11   2017-01       2017-01       2016-12
# 4        2018-01    2017-12      2017-11   2017-01       2017-01       2016-12
# ...          ...        ...          ...       ...           ...           ...
# 2212388  2022-03    2022-02      2022-01   2021-03       2021-03       2021-02
# 2212389  2022-03    2022-02      2022-01   2021-03       2021-03       2021-02
# 2212390  2022-03    2022-02      2022-01   2021-03       2021-03       2021-02
# 2212391  2022-03    2022-02      2022-01   2021-03       2021-03       2021-02
# 2212392  2022-03    2022-02      2022-01   2021-03       2021-03       2021-02
#
# [2212393 rows x 17 columns]

# %%
data = data.merge(data[['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'PATIENT_ID_COUNT', 'DATE']], 
                  left_on=['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'PREV_MONTH'], 
                  right_on=['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_month'), how='left')
data = data.merge(data[['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'PATIENT_ID_COUNT', 'DATE']], 
                  left_on=['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'PREV_YEAR'], 
                  right_on=['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_year'), how='left')
data = data.merge(data[['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'PATIENT_ID_COUNT', 'DATE']], 
                  left_on=['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'PREV_2_MONTH'], 
                  right_on=['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_2_month'), how='left')
data = data.merge(data[['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'PATIENT_ID_COUNT', 'DATE']], 
                  left_on=['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'PREV_11_MONTH'], 
                  right_on=['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_11_month'), how='left')
data = data.merge(data[['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'PATIENT_ID_COUNT', 'DATE']], 
                  left_on=['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'PREV_13_MONTH'], 
                  right_on=['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_13_month'), how='left')

# %%
agg_data = data.groupby(['PATIENT_SEX', 'MKB_CODE', 'size', 'AGE_CATEGORY', 'DATE'])['PATIENT_ID_COUNT'].mean().reset_index()
data = data.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'MKB_CODE', 'size', 'AGE_CATEGORY', 'PREV_MONTH'], 
                  right_on=['PATIENT_SEX', 'MKB_CODE', 'size', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_month_size'), how='left')
data = data.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'MKB_CODE', 'size', 'AGE_CATEGORY', 'PREV_YEAR'], 
                  right_on=['PATIENT_SEX', 'MKB_CODE', 'size', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_year_size'), how='left')
data = data.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'MKB_CODE', 'size', 'AGE_CATEGORY', 'PREV_2_MONTH'], 
                  right_on=['PATIENT_SEX', 'MKB_CODE', 'size', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_2_month_size'), how='left')
data = data.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'MKB_CODE', 'size', 'AGE_CATEGORY', 'PREV_11_MONTH'], 
                  right_on=['PATIENT_SEX', 'MKB_CODE', 'size', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_11_month_size'), how='left')
data = data.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'MKB_CODE', 'size', 'AGE_CATEGORY', 'PREV_13_MONTH'], 
                  right_on=['PATIENT_SEX', 'MKB_CODE', 'size', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_13_month_size'), how='left')

# %%
agg_data = data.groupby(['PATIENT_SEX', 'CODE_TYPE', 'ADRES', 'AGE_CATEGORY', 'DATE'])['PATIENT_ID_COUNT'].mean().reset_index()
data = data.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'CODE_TYPE', 'ADRES', 'AGE_CATEGORY', 'PREV_MONTH'], 
                  right_on=['PATIENT_SEX', 'CODE_TYPE', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_month_code_type'), how='left')
data = data.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'CODE_TYPE', 'ADRES', 'AGE_CATEGORY', 'PREV_YEAR'], 
                  right_on=['PATIENT_SEX', 'CODE_TYPE', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_year_code_type'), how='left')
data = data.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'CODE_TYPE', 'ADRES', 'AGE_CATEGORY', 'PREV_2_MONTH'], 
                  right_on=['PATIENT_SEX', 'CODE_TYPE', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_2_month_code_type'), how='left')
data = data.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'CODE_TYPE', 'ADRES', 'AGE_CATEGORY', 'PREV_11_MONTH'], 
                  right_on=['PATIENT_SEX', 'CODE_TYPE', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_11_month_code_type'), how='left')
data = data.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'CODE_TYPE', 'ADRES', 'AGE_CATEGORY', 'PREV_13_MONTH'], 
                  right_on=['PATIENT_SEX', 'CODE_TYPE', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_13_month_code_type'), how='left')

# %%
agg_data = data.groupby(['PATIENT_SEX', 'CODE_CATEGORY', 'ADRES', 'AGE_CATEGORY', 'DATE'])['PATIENT_ID_COUNT'].mean().reset_index()
data = data.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'CODE_CATEGORY', 'ADRES', 'AGE_CATEGORY', 'PREV_MONTH'], 
                  right_on=['PATIENT_SEX', 'CODE_CATEGORY', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_month_code_category'), how='left')
data = data.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'CODE_CATEGORY', 'ADRES', 'AGE_CATEGORY', 'PREV_YEAR'], 
                  right_on=['PATIENT_SEX', 'CODE_CATEGORY', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_year_code_category'), how='left')
data = data.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'CODE_CATEGORY', 'ADRES', 'AGE_CATEGORY', 'PREV_2_MONTH'], 
                  right_on=['PATIENT_SEX', 'CODE_CATEGORY', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_2_month_code_category'), how='left')
data = data.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'CODE_CATEGORY', 'ADRES', 'AGE_CATEGORY', 'PREV_11_MONTH'], 
                  right_on=['PATIENT_SEX', 'CODE_CATEGORY', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_11_month_code_category'), how='left')
data = data.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'CODE_CATEGORY', 'ADRES', 'AGE_CATEGORY', 'PREV_13_MONTH'], 
                  right_on=['PATIENT_SEX', 'CODE_CATEGORY', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_13_month_code_category'), how='left')

# %%
test = test.merge(data[['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'PATIENT_ID_COUNT', 'DATE']], 
                  left_on=['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'PREV_MONTH'], 
                  right_on=['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_month'), how='left')
test = test.merge(data[['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'PATIENT_ID_COUNT', 'DATE']], 
                  left_on=['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'PREV_YEAR'], 
                  right_on=['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_year'), how='left')
test = test.merge(data[['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'PATIENT_ID_COUNT', 'DATE']], 
                  left_on=['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'PREV_2_MONTH'], 
                  right_on=['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_2_month'), how='left')
test = test.merge(data[['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'PATIENT_ID_COUNT', 'DATE']], 
                  left_on=['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'PREV_11_MONTH'], 
                  right_on=['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_11_month'), how='left')
test = test.merge(data[['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'PATIENT_ID_COUNT', 'DATE']], 
                  left_on=['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'PREV_13_MONTH'], 
                  right_on=['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_13_month'), how='left')

# %%
agg_data = data.groupby(['PATIENT_SEX', 'MKB_CODE', 'size', 'AGE_CATEGORY', 'DATE'])['PATIENT_ID_COUNT'].mean().reset_index()
test = test.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'MKB_CODE', 'size', 'AGE_CATEGORY', 'PREV_MONTH'], 
                  right_on=['PATIENT_SEX', 'MKB_CODE', 'size', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_month_size'), how='left')
test = test.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'MKB_CODE', 'size', 'AGE_CATEGORY', 'PREV_YEAR'], 
                  right_on=['PATIENT_SEX', 'MKB_CODE', 'size', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_year_size'), how='left')
test = test.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'MKB_CODE', 'size', 'AGE_CATEGORY', 'PREV_2_MONTH'], 
                  right_on=['PATIENT_SEX', 'MKB_CODE', 'size', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_2_month_size'), how='left')
test = test.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'MKB_CODE', 'size', 'AGE_CATEGORY', 'PREV_11_MONTH'], 
                  right_on=['PATIENT_SEX', 'MKB_CODE', 'size', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_11_month_size'), how='left')
test = test.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'MKB_CODE', 'size', 'AGE_CATEGORY', 'PREV_13_MONTH'], 
                  right_on=['PATIENT_SEX', 'MKB_CODE', 'size', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_13_month_size'), how='left')

# %%
agg_data = data.groupby(['PATIENT_SEX', 'CODE_TYPE', 'ADRES', 'AGE_CATEGORY', 'DATE'])['PATIENT_ID_COUNT'].mean().reset_index()
test = test.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'CODE_TYPE', 'ADRES', 'AGE_CATEGORY', 'PREV_MONTH'], 
                  right_on=['PATIENT_SEX', 'CODE_TYPE', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_month_code_type'), how='left')
test = test.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'CODE_TYPE', 'ADRES', 'AGE_CATEGORY', 'PREV_YEAR'], 
                  right_on=['PATIENT_SEX', 'CODE_TYPE', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_year_code_type'), how='left')
test = test.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'CODE_TYPE', 'ADRES', 'AGE_CATEGORY', 'PREV_2_MONTH'], 
                  right_on=['PATIENT_SEX', 'CODE_TYPE', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_2_month_code_type'), how='left')
test = test.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'CODE_TYPE', 'ADRES', 'AGE_CATEGORY', 'PREV_11_MONTH'], 
                  right_on=['PATIENT_SEX', 'CODE_TYPE', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_11_month_code_type'), how='left')
test = test.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'CODE_TYPE', 'ADRES', 'AGE_CATEGORY', 'PREV_13_MONTH'], 
                  right_on=['PATIENT_SEX', 'CODE_TYPE', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_13_month_code_type'), how='left')

# %%
agg_data = data.groupby(['PATIENT_SEX', 'CODE_CATEGORY', 'ADRES', 'AGE_CATEGORY', 'DATE'])['PATIENT_ID_COUNT'].mean().reset_index()
test = test.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'CODE_CATEGORY', 'ADRES', 'AGE_CATEGORY', 'PREV_MONTH'], 
                  right_on=['PATIENT_SEX', 'CODE_CATEGORY', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_month_code_category'), how='left')
test = test.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'CODE_CATEGORY', 'ADRES', 'AGE_CATEGORY', 'PREV_YEAR'], 
                  right_on=['PATIENT_SEX', 'CODE_CATEGORY', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_year_code_category'), how='left')
test = test.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'CODE_CATEGORY', 'ADRES', 'AGE_CATEGORY', 'PREV_2_MONTH'], 
                  right_on=['PATIENT_SEX', 'CODE_CATEGORY', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_2_month_code_category'), how='left')
test = test.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'CODE_CATEGORY', 'ADRES', 'AGE_CATEGORY', 'PREV_11_MONTH'], 
                  right_on=['PATIENT_SEX', 'CODE_CATEGORY', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_11_month_code_category'), how='left')
test = test.merge(agg_data, 
                  left_on=['PATIENT_SEX', 'CODE_CATEGORY', 'ADRES', 'AGE_CATEGORY', 'PREV_13_MONTH'], 
                  right_on=['PATIENT_SEX', 'CODE_CATEGORY', 'ADRES', 'AGE_CATEGORY', 'DATE'], suffixes=('', '_prev_13_month_code_category'), how='left')

# %%
test.rename({'PATIENT_ID_COUNT': 'PATIENT_ID_COUNT_prev_month'}, axis=1, inplace=True)

# %%
train = data[(data['YEAR'] <= 2020) | ((data['YEAR'] == 2021) & (data['MONTH'] < 4))]
val = data[(data['YEAR'] == 2021) & (data['MONTH'] == 4)]

# %%
train.columns
# Out:
# Index(['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'PATIENT_ID_COUNT',
#        'MONTH', 'YEAR', 'CODE_TYPE', 'CODE_CATEGORY', 'size', 'DAY', 'DATE',
#        'PREV_MONTH', 'PREV_2_MONTH', 'PREV_YEAR', 'PREV_11_MONTH',
#        'PREV_13_MONTH', 'PATIENT_ID_COUNT_prev_month', 'DATE_prev_month',
#        'PATIENT_ID_COUNT_prev_year', 'DATE_prev_year',
#        'PATIENT_ID_COUNT_prev_2_month', 'DATE_prev_2_month',
#        'PATIENT_ID_COUNT_prev_11_month', 'DATE_prev_11_month',
#        'PATIENT_ID_COUNT_prev_13_month', 'DATE_prev_13_month',
#        'DATE_prev_month_size', 'PATIENT_ID_COUNT_prev_month_size',
#        'DATE_prev_year_size', 'PATIENT_ID_COUNT_prev_year_size',
#        'DATE_prev_2_month_size', 'PATIENT_ID_COUNT_prev_2_month_size',
#        'DATE_prev_11_month_size', 'PATIENT_ID_COUNT_prev_11_month_size',
#        'DATE_prev_13_month_size', 'PATIENT_ID_COUNT_prev_13_month_size',
#        'DATE_prev_month_code_type', 'PATIENT_ID_COUNT_prev_month_code_type',
#        'DATE_prev_year_code_type', 'PATIENT_ID_COUNT_prev_year_code_type',
#        'DATE_prev_2_month_code_type',
#        'PATIENT_ID_COUNT_prev_2_month_code_type',
#        'DATE_prev_11_month_code_type',
#        'PATIENT_ID_COUNT_prev_11_month_code_type',
#        'DATE_prev_13_month_code_type',
#        'PATIENT_ID_COUNT_prev_13_month_code_type',
#        'DATE_prev_month_code_category',
#        'PATIENT_ID_COUNT_prev_month_code_category',
#        'DATE_prev_year_code_category',
#        'PATIENT_ID_COUNT_prev_year_code_category',
#        'DATE_prev_2_month_code_category',
#        'PATIENT_ID_COUNT_prev_2_month_code_category',
#        'DATE_prev_11_month_code_category',
#        'PATIENT_ID_COUNT_prev_11_month_code_category',
#        'DATE_prev_13_month_code_category',
#        'PATIENT_ID_COUNT_prev_13_month_code_category'],
#       dtype='object')

# %%
drop_fields = [
    'YEAR', 'DATE', 'PREV_MONTH',  'PREV_YEAR', 'PREV_2_MONTH', 'PREV_11_MONTH', 'PREV_13_MONTH', 
    'DATE_prev_month', 'DATE_prev_year', 'DATE_prev_2_month', 'DATE_prev_11_month', 'DATE_prev_13_month',
    'DATE_prev_month_size', 'DATE_prev_year_size', 'DATE_prev_2_month_size', 'DATE_prev_11_month_size', 'DATE_prev_13_month_size',
    'DATE_prev_month_code_type', 'DATE_prev_year_code_type', 'DATE_prev_2_month_code_type', 'DATE_prev_11_month_code_type', 'DATE_prev_13_month_code_type',
    'DATE_prev_month_code_category', 'DATE_prev_year_code_category', 'DATE_prev_2_month_code_category', 'DATE_prev_11_month_code_category', 'DATE_prev_13_month_code_category',
]
data.drop(drop_fields, axis=1, inplace=True)
train.drop(drop_fields, axis=1, inplace=True)
val.drop(drop_fields, axis=1, inplace=True)
test.drop(drop_fields, axis=1, inplace=True)
# Out:
# /Users/vladimirfomenko/.virtualenvs/ml/lib/python3.9/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
train
# Out:
#          PATIENT_SEX MKB_CODE                     ADRES AGE_CATEGORY  \
# 0                  0    A02.0               Калининград     children
# 1                  0    A02.0               Калининград      elderly
# 2                  0    A02.0               Калининград        young
# 3                  0    A02.0  СТ Искра ул. Тюльпановая     children
# 4                  0      A02               Калининград     children
# ...              ...      ...                       ...          ...
# 1820827            1    Z96.6               Калининград    middleage
# 1820828            1    Z96.6               Калининград        young
# 1820829            1    Z96.6                    Озерск    middleage
# 1820830            1    Z96.6                Пионерский        young
# 1820831            1    Z96.6                   Советск        young
#
#          PATIENT_ID_COUNT  MONTH CODE_TYPE CODE_CATEGORY  size  DAY  ...  \
# 0                       3      1         A           A02     4    1  ...
# 1                       1      1         A           A02     4    1  ...
# 2                       2      1         A           A02     4    1  ...
# 3                       1      1         A           A02     1    1  ...
# 4                       1      1         A           A02     4    1  ...
# ...                   ...    ...       ...           ...   ...  ...  ...
# 1820827                 3      3         Z           Z96     4    1  ...
# 1820828                 1      3         Z           Z96     4    1  ...
# 1820829                 1      3         Z           Z96     2    1  ...
# 1820830                 1      3         Z           Z96     3    1  ...
# 1820831                 1      3         Z           Z96     3    1  ...
#
#          PATIENT_ID_COUNT_prev_month_code_type  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 1820827                              77.294118
# 1820828                              68.187500
# 1820829                              19.333333
# 1820830                               6.450000
# 1820831                               2.700000
#
#          PATIENT_ID_COUNT_prev_year_code_type  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 1820827                             17.050847
# 1820828                             39.273973
# 1820829                              1.200000
# 1820830                              5.571429
# 1820831                              2.357143
#
#          PATIENT_ID_COUNT_prev_2_month_code_type  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 1820827                                41.000000
# 1820828                                40.397059
# 1820829                                 5.666667
# 1820830                                 5.933333
# 1820831                                 2.000000
#
#          PATIENT_ID_COUNT_prev_11_month_code_type  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 1820827                                 17.050847
# 1820828                                 39.273973
# 1820829                                  1.200000
# 1820830                                  5.571429
# 1820831                                  2.357143
#
#          PATIENT_ID_COUNT_prev_13_month_code_type  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 1820827                                 17.019608
# 1820828                                 35.388889
# 1820829                                  3.000000
# 1820830                                  5.538462
# 1820831                                  3.200000
#
#          PATIENT_ID_COUNT_prev_month_code_category  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 1820827                                        1.0
# 1820828                                        1.0
# 1820829                                        NaN
# 1820830                                        NaN
# 1820831                                        NaN
#
#          PATIENT_ID_COUNT_prev_year_code_category  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 1820827                                       NaN
# 1820828                                       NaN
# 1820829                                       NaN
# 1820830                                       NaN
# 1820831                                       NaN
#
#          PATIENT_ID_COUNT_prev_2_month_code_category  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 1820827                                          NaN
# 1820828                                          NaN
# 1820829                                          NaN
# 1820830                                          NaN
# 1820831                                          NaN
#
#          PATIENT_ID_COUNT_prev_11_month_code_category  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 1820827                                           NaN
# 1820828                                           NaN
# 1820829                                           NaN
# 1820830                                           NaN
# 1820831                                           NaN
#
#          PATIENT_ID_COUNT_prev_13_month_code_category
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 1820827                                           NaN
# 1820828                                           NaN
# 1820829                                           NaN
# 1820830                                           NaN
# 1820831                                           NaN
#
# [1820832 rows x 30 columns]

# %%
val_preds = []
for train_index, test_index in KFold(n_splits=5).split(train):

    model = CatBoostRegressor(
        eval_metric='R2',
        early_stopping_rounds=20,
        cat_features=['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'CODE_TYPE', 'MONTH', 'size', 'CODE_CATEGORY']
    )
    model.fit(
        train.iloc[train_index].drop('PATIENT_ID_COUNT', axis=1), train.iloc[train_index]['PATIENT_ID_COUNT'], 
        eval_set=(val.drop('PATIENT_ID_COUNT', axis=1), val['PATIENT_ID_COUNT'])
    )
    val_preds.append(model.predict(val.drop('PATIENT_ID_COUNT', axis=1)))
# Out:
# Learning rate set to 0.159788
# 0:	learn: 0.2410143	test: 0.2035919	best: 0.2035919 (0)	total: 672ms	remaining: 11m 11s
# 1:	learn: 0.4191100	test: 0.3323445	best: 0.3323445 (1)	total: 1.28s	remaining: 10m 39s
# 2:	learn: 0.5497697	test: 0.4614591	best: 0.4614591 (2)	total: 1.77s	remaining: 9m 47s
# 3:	learn: 0.6443299	test: 0.5449829	best: 0.5449829 (3)	total: 2.24s	remaining: 9m 17s
# 4:	learn: 0.7131086	test: 0.5896533	best: 0.5896533 (4)	total: 2.75s	remaining: 9m 6s
# 5:	learn: 0.7642505	test: 0.6237408	best: 0.6237408 (5)	total: 3.22s	remaining: 8m 53s
# 6:	learn: 0.8013997	test: 0.6635546	best: 0.6635546 (6)	total: 3.61s	remaining: 8m 32s
# 7:	learn: 0.8282829	test: 0.6930999	best: 0.6930999 (7)	total: 3.99s	remaining: 8m 14s
# 8:	learn: 0.8494397	test: 0.7026951	best: 0.7026951 (8)	total: 4.35s	remaining: 7m 59s
# 9:	learn: 0.8658444	test: 0.7152265	best: 0.7152265 (9)	total: 4.75s	remaining: 7m 50s
# 10:	learn: 0.8778080	test: 0.7319890	best: 0.7319890 (10)	total: 5.19s	remaining: 7m 47s
# 11:	learn: 0.8876797	test: 0.7393509	best: 0.7393509 (11)	total: 5.52s	remaining: 7m 34s
# 12:	learn: 0.8949345	test: 0.7525156	best: 0.7525156 (12)	total: 6.04s	remaining: 7m 38s
# 13:	learn: 0.8996073	test: 0.7625424	best: 0.7625424 (13)	total: 6.5s	remaining: 7m 38s
# 14:	learn: 0.9038728	test: 0.7723900	best: 0.7723900 (14)	total: 6.95s	remaining: 7m 36s
# 15:	learn: 0.9077607	test: 0.7797276	best: 0.7797276 (15)	total: 7.35s	remaining: 7m 32s
# 16:	learn: 0.9119794	test: 0.7839753	best: 0.7839753 (16)	total: 7.74s	remaining: 7m 27s
# 17:	learn: 0.9145940	test: 0.7897059	best: 0.7897059 (17)	total: 8.12s	remaining: 7m 22s
# 18:	learn: 0.9173765	test: 0.7901852	best: 0.7901852 (18)	total: 8.49s	remaining: 7m 18s
# 19:	learn: 0.9201137	test: 0.7900199	best: 0.7901852 (18)	total: 8.87s	remaining: 7m 14s
# 20:	learn: 0.9220286	test: 0.7909446	best: 0.7909446 (20)	total: 9.29s	remaining: 7m 12s
# 21:	learn: 0.9238515	test: 0.7933914	best: 0.7933914 (21)	total: 9.65s	remaining: 7m 9s
# 22:	learn: 0.9255659	test: 0.7901410	best: 0.7933914 (21)	total: 10s	remaining: 7m 5s
# 23:	learn: 0.9271700	test: 0.7924367	best: 0.7933914 (21)	total: 10.4s	remaining: 7m 2s
# 24:	learn: 0.9285815	test: 0.7983845	best: 0.7983845 (24)	total: 10.7s	remaining: 6m 58s
# 25:	learn: 0.9304226	test: 0.8073649	best: 0.8073649 (25)	total: 11.1s	remaining: 6m 56s
# 26:	learn: 0.9320737	test: 0.8100448	best: 0.8100448 (26)	total: 11.5s	remaining: 6m 53s
# 27:	learn: 0.9332785	test: 0.8105370	best: 0.8105370 (27)	total: 11.8s	remaining: 6m 50s
# 28:	learn: 0.9341692	test: 0.8128381	best: 0.8128381 (28)	total: 12.2s	remaining: 6m 47s
# 29:	learn: 0.9349693	test: 0.8131764	best: 0.8131764 (29)	total: 12.5s	remaining: 6m 45s
# 30:	learn: 0.9359350	test: 0.8143477	best: 0.8143477 (30)	total: 12.9s	remaining: 6m 44s
# 31:	learn: 0.9365047	test: 0.8176502	best: 0.8176502 (31)	total: 13.3s	remaining: 6m 42s
# 32:	learn: 0.9373276	test: 0.8188966	best: 0.8188966 (32)	total: 13.7s	remaining: 6m 40s
# 33:	learn: 0.9380400	test: 0.8200571	best: 0.8200571 (33)	total: 14s	remaining: 6m 36s
# 34:	learn: 0.9384552	test: 0.8198775	best: 0.8200571 (33)	total: 14.4s	remaining: 6m 36s
# 35:	learn: 0.9395182	test: 0.8236207	best: 0.8236207 (35)	total: 14.7s	remaining: 6m 33s
# 36:	learn: 0.9400723	test: 0.8238432	best: 0.8238432 (36)	total: 15.1s	remaining: 6m 31s
# 37:	learn: 0.9406536	test: 0.8248672	best: 0.8248672 (37)	total: 15.4s	remaining: 6m 30s
# 38:	learn: 0.9415189	test: 0.8235868	best: 0.8248672 (37)	total: 15.8s	remaining: 6m 29s
# 39:	learn: 0.9423107	test: 0.8233312	best: 0.8248672 (37)	total: 16.2s	remaining: 6m 28s
# 40:	learn: 0.9425998	test: 0.8226796	best: 0.8248672 (37)	total: 16.6s	remaining: 6m 27s
# 41:	learn: 0.9430616	test: 0.8236360	best: 0.8248672 (37)	total: 17s	remaining: 6m 27s
# 42:	learn: 0.9435871	test: 0.8226222	best: 0.8248672 (37)	total: 17.4s	remaining: 6m 27s
# 43:	learn: 0.9440339	test: 0.8230150	best: 0.8248672 (37)	total: 17.8s	remaining: 6m 25s
# 44:	learn: 0.9444570	test: 0.8230888	best: 0.8248672 (37)	total: 18.1s	remaining: 6m 24s
# 45:	learn: 0.9448976	test: 0.8212942	best: 0.8248672 (37)	total: 18.6s	remaining: 6m 25s
# 46:	learn: 0.9454431	test: 0.8208626	best: 0.8248672 (37)	total: 18.9s	remaining: 6m 23s
# 47:	learn: 0.9460784	test: 0.8206618	best: 0.8248672 (37)	total: 19.3s	remaining: 6m 23s
# 48:	learn: 0.9464875	test: 0.8210228	best: 0.8248672 (37)	total: 19.6s	remaining: 6m 20s
# 49:	learn: 0.9466720	test: 0.8209479	best: 0.8248672 (37)	total: 19.9s	remaining: 6m 18s
# 50:	learn: 0.9476543	test: 0.8200254	best: 0.8248672 (37)	total: 20.3s	remaining: 6m 17s
# 51:	learn: 0.9479219	test: 0.8200241	best: 0.8248672 (37)	total: 20.7s	remaining: 6m 17s
# 52:	learn: 0.9482299	test: 0.8191272	best: 0.8248672 (37)	total: 21.1s	remaining: 6m 16s
# 53:	learn: 0.9485633	test: 0.8166293	best: 0.8248672 (37)	total: 21.5s	remaining: 6m 16s
# 54:	learn: 0.9488416	test: 0.8161395	best: 0.8248672 (37)	total: 21.9s	remaining: 6m 15s
# 55:	learn: 0.9490960	test: 0.8161093	best: 0.8248672 (37)	total: 22.2s	remaining: 6m 14s
# 56:	learn: 0.9494384	test: 0.8163293	best: 0.8248672 (37)	total: 22.6s	remaining: 6m 14s
# 57:	learn: 0.9501775	test: 0.8121442	best: 0.8248672 (37)	total: 23s	remaining: 6m 13s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.824867187
# bestIteration = 37
#
# Shrink model to first 38 iterations.
# Learning rate set to 0.159788
# 0:	learn: 0.2354910	test: 0.1907236	best: 0.1907236 (0)	total: 494ms	remaining: 8m 13s
# 1:	learn: 0.4082896	test: 0.3487542	best: 0.3487542 (1)	total: 998ms	remaining: 8m 18s
# 2:	learn: 0.5308078	test: 0.4522994	best: 0.4522994 (2)	total: 1.49s	remaining: 8m 15s
# 3:	learn: 0.6183669	test: 0.5295506	best: 0.5295506 (3)	total: 2.01s	remaining: 8m 20s
# 4:	learn: 0.6860292	test: 0.6026519	best: 0.6026519 (4)	total: 2.44s	remaining: 8m 6s
# 5:	learn: 0.7356784	test: 0.6580684	best: 0.6580684 (5)	total: 2.98s	remaining: 8m 14s
# 6:	learn: 0.7733724	test: 0.6813893	best: 0.6813893 (6)	total: 3.4s	remaining: 8m 2s
# 7:	learn: 0.8000487	test: 0.7101394	best: 0.7101394 (7)	total: 3.87s	remaining: 8m
# 8:	learn: 0.8218021	test: 0.7358735	best: 0.7358735 (8)	total: 4.3s	remaining: 7m 53s
# 9:	learn: 0.8378841	test: 0.7490537	best: 0.7490537 (9)	total: 4.71s	remaining: 7m 46s
# 10:	learn: 0.8503536	test: 0.7582224	best: 0.7582224 (10)	total: 5.08s	remaining: 7m 36s
# 11:	learn: 0.8605248	test: 0.7716465	best: 0.7716465 (11)	total: 5.46s	remaining: 7m 29s
# 12:	learn: 0.8676258	test: 0.7841063	best: 0.7841063 (12)	total: 5.9s	remaining: 7m 28s
# 13:	learn: 0.8740174	test: 0.7849295	best: 0.7849295 (13)	total: 6.24s	remaining: 7m 19s
# 14:	learn: 0.8798015	test: 0.7925050	best: 0.7925050 (14)	total: 6.64s	remaining: 7m 15s
# 15:	learn: 0.8845536	test: 0.7929297	best: 0.7929297 (15)	total: 7.03s	remaining: 7m 12s
# 16:	learn: 0.8888192	test: 0.8021437	best: 0.8021437 (16)	total: 7.47s	remaining: 7m 11s
# 17:	learn: 0.8926606	test: 0.8033769	best: 0.8033769 (17)	total: 7.83s	remaining: 7m 7s
# 18:	learn: 0.8959199	test: 0.8086960	best: 0.8086960 (18)	total: 8.21s	remaining: 7m 3s
# 19:	learn: 0.8989071	test: 0.8107323	best: 0.8107323 (19)	total: 8.59s	remaining: 7m
# 20:	learn: 0.9006154	test: 0.8158643	best: 0.8158643 (20)	total: 9.03s	remaining: 7m 1s
# 21:	learn: 0.9030435	test: 0.8162813	best: 0.8162813 (21)	total: 9.35s	remaining: 6m 55s
# 22:	learn: 0.9039412	test: 0.8181179	best: 0.8181179 (22)	total: 9.73s	remaining: 6m 53s
# 23:	learn: 0.9061551	test: 0.8230124	best: 0.8230124 (23)	total: 10.1s	remaining: 6m 52s
# 24:	learn: 0.9072645	test: 0.8257197	best: 0.8257197 (24)	total: 10.6s	remaining: 6m 52s
# 25:	learn: 0.9087888	test: 0.8270590	best: 0.8270590 (25)	total: 11s	remaining: 6m 50s
# 26:	learn: 0.9101136	test: 0.8282607	best: 0.8282607 (26)	total: 11.4s	remaining: 6m 49s
# 27:	learn: 0.9112183	test: 0.8280294	best: 0.8282607 (26)	total: 11.8s	remaining: 6m 48s
# 28:	learn: 0.9123642	test: 0.8303635	best: 0.8303635 (28)	total: 12.1s	remaining: 6m 46s
# 29:	learn: 0.9129918	test: 0.8319255	best: 0.8319255 (29)	total: 12.5s	remaining: 6m 44s
# 30:	learn: 0.9142677	test: 0.8359082	best: 0.8359082 (30)	total: 12.9s	remaining: 6m 42s
# 31:	learn: 0.9148287	test: 0.8370069	best: 0.8370069 (31)	total: 13.2s	remaining: 6m 40s
# 32:	learn: 0.9158032	test: 0.8396942	best: 0.8396942 (32)	total: 13.6s	remaining: 6m 38s
# 33:	learn: 0.9165855	test: 0.8410201	best: 0.8410201 (33)	total: 13.9s	remaining: 6m 35s
# 34:	learn: 0.9173208	test: 0.8394472	best: 0.8410201 (33)	total: 14.3s	remaining: 6m 34s
# 35:	learn: 0.9177412	test: 0.8429652	best: 0.8429652 (35)	total: 14.7s	remaining: 6m 33s
# 36:	learn: 0.9182155	test: 0.8429656	best: 0.8429656 (36)	total: 15.1s	remaining: 6m 32s
# 37:	learn: 0.9185071	test: 0.8433159	best: 0.8433159 (37)	total: 15.5s	remaining: 6m 32s
# 38:	learn: 0.9187661	test: 0.8443223	best: 0.8443223 (38)	total: 15.9s	remaining: 6m 31s
# 39:	learn: 0.9196070	test: 0.8449842	best: 0.8449842 (39)	total: 16.3s	remaining: 6m 30s
# 40:	learn: 0.9200511	test: 0.8461145	best: 0.8461145 (40)	total: 16.7s	remaining: 6m 29s
# 41:	learn: 0.9207224	test: 0.8456861	best: 0.8461145 (40)	total: 17s	remaining: 6m 28s
# 42:	learn: 0.9214053	test: 0.8478356	best: 0.8478356 (42)	total: 17.4s	remaining: 6m 27s
# 43:	learn: 0.9218434	test: 0.8470045	best: 0.8478356 (42)	total: 17.7s	remaining: 6m 25s
# 44:	learn: 0.9230912	test: 0.8476689	best: 0.8478356 (42)	total: 18.1s	remaining: 6m 23s
# 45:	learn: 0.9235203	test: 0.8482868	best: 0.8482868 (45)	total: 18.5s	remaining: 6m 23s
# 46:	learn: 0.9248971	test: 0.8475698	best: 0.8482868 (45)	total: 18.9s	remaining: 6m 22s
# 47:	learn: 0.9251495	test: 0.8479036	best: 0.8482868 (45)	total: 19.2s	remaining: 6m 21s
# 48:	learn: 0.9255336	test: 0.8485087	best: 0.8485087 (48)	total: 19.6s	remaining: 6m 20s
# 49:	learn: 0.9257353	test: 0.8491098	best: 0.8491098 (49)	total: 19.8s	remaining: 6m 16s
# 50:	learn: 0.9289277	test: 0.8495125	best: 0.8495125 (50)	total: 20.2s	remaining: 6m 15s
# 51:	learn: 0.9297419	test: 0.8486601	best: 0.8495125 (50)	total: 20.5s	remaining: 6m 13s
# 52:	learn: 0.9301466	test: 0.8486268	best: 0.8495125 (50)	total: 20.9s	remaining: 6m 13s
# 53:	learn: 0.9308372	test: 0.8466418	best: 0.8495125 (50)	total: 21.3s	remaining: 6m 12s
# 54:	learn: 0.9335229	test: 0.8469530	best: 0.8495125 (50)	total: 21.6s	remaining: 6m 10s
# 55:	learn: 0.9336932	test: 0.8471941	best: 0.8495125 (50)	total: 21.9s	remaining: 6m 9s
# 56:	learn: 0.9340059	test: 0.8457690	best: 0.8495125 (50)	total: 22.3s	remaining: 6m 8s
# 57:	learn: 0.9344343	test: 0.8459275	best: 0.8495125 (50)	total: 22.6s	remaining: 6m 7s
# 58:	learn: 0.9348429	test: 0.8469034	best: 0.8495125 (50)	total: 23s	remaining: 6m 6s
# 59:	learn: 0.9354243	test: 0.8452628	best: 0.8495125 (50)	total: 23.4s	remaining: 6m 6s
# 60:	learn: 0.9358806	test: 0.8454415	best: 0.8495125 (50)	total: 23.8s	remaining: 6m 5s
# 61:	learn: 0.9361371	test: 0.8468533	best: 0.8495125 (50)	total: 24.1s	remaining: 6m 4s
# 62:	learn: 0.9364923	test: 0.8481773	best: 0.8495125 (50)	total: 24.5s	remaining: 6m 4s
# 63:	learn: 0.9366596	test: 0.8483095	best: 0.8495125 (50)	total: 24.8s	remaining: 6m 3s
# 64:	learn: 0.9368061	test: 0.8471723	best: 0.8495125 (50)	total: 25.3s	remaining: 6m 4s
# 65:	learn: 0.9371763	test: 0.8482072	best: 0.8495125 (50)	total: 25.7s	remaining: 6m 3s
# 66:	learn: 0.9376602	test: 0.8469731	best: 0.8495125 (50)	total: 26.1s	remaining: 6m 2s
# 67:	learn: 0.9379293	test: 0.8465713	best: 0.8495125 (50)	total: 26.4s	remaining: 6m 1s
# 68:	learn: 0.9381112	test: 0.8465714	best: 0.8495125 (50)	total: 26.7s	remaining: 6m
# 69:	learn: 0.9381865	test: 0.8466885	best: 0.8495125 (50)	total: 27.1s	remaining: 6m
# 70:	learn: 0.9383358	test: 0.8465833	best: 0.8495125 (50)	total: 27.5s	remaining: 6m
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.8495124793
# bestIteration = 50
#
# Shrink model to first 51 iterations.
# Learning rate set to 0.159788
# 0:	learn: 0.2383143	test: 0.2004072	best: 0.2004072 (0)	total: 554ms	remaining: 9m 13s
# 1:	learn: 0.4093708	test: 0.3514515	best: 0.3514515 (1)	total: 1.01s	remaining: 8m 25s
# 2:	learn: 0.5357400	test: 0.4650814	best: 0.4650814 (2)	total: 1.55s	remaining: 8m 35s
# 3:	learn: 0.6273318	test: 0.5588868	best: 0.5588868 (3)	total: 2.04s	remaining: 8m 29s
# 4:	learn: 0.6919261	test: 0.6213761	best: 0.6213761 (4)	total: 2.52s	remaining: 8m 21s
# 5:	learn: 0.7393281	test: 0.6740260	best: 0.6740260 (5)	total: 2.92s	remaining: 8m 3s
# 6:	learn: 0.7759539	test: 0.6902015	best: 0.6902015 (6)	total: 3.35s	remaining: 7m 55s
# 7:	learn: 0.8022293	test: 0.7243551	best: 0.7243551 (7)	total: 3.78s	remaining: 7m 49s
# 8:	learn: 0.8233925	test: 0.7374411	best: 0.7374411 (8)	total: 4.21s	remaining: 7m 43s
# 9:	learn: 0.8397577	test: 0.7488698	best: 0.7488698 (9)	total: 4.62s	remaining: 7m 37s
# 10:	learn: 0.8523601	test: 0.7548692	best: 0.7548692 (10)	total: 4.97s	remaining: 7m 27s
# 11:	learn: 0.8630562	test: 0.7627931	best: 0.7627931 (11)	total: 5.36s	remaining: 7m 21s
# 12:	learn: 0.8709312	test: 0.7766027	best: 0.7766027 (12)	total: 5.69s	remaining: 7m 12s
# 13:	learn: 0.8771037	test: 0.7899962	best: 0.7899962 (13)	total: 6.09s	remaining: 7m 9s
# 14:	learn: 0.8836455	test: 0.7945419	best: 0.7945419 (14)	total: 6.53s	remaining: 7m 9s
# 15:	learn: 0.8873157	test: 0.7979534	best: 0.7979534 (15)	total: 6.93s	remaining: 7m 6s
# 16:	learn: 0.8918034	test: 0.7961732	best: 0.7979534 (15)	total: 7.32s	remaining: 7m 3s
# 17:	learn: 0.8948555	test: 0.8010406	best: 0.8010406 (17)	total: 7.76s	remaining: 7m 3s
# 18:	learn: 0.8980915	test: 0.8019542	best: 0.8019542 (18)	total: 8.12s	remaining: 6m 59s
# 19:	learn: 0.9004181	test: 0.8003056	best: 0.8019542 (18)	total: 8.44s	remaining: 6m 53s
# 20:	learn: 0.9025130	test: 0.8010563	best: 0.8019542 (18)	total: 8.78s	remaining: 6m 49s
# 21:	learn: 0.9056975	test: 0.8001188	best: 0.8019542 (18)	total: 9.16s	remaining: 6m 47s
# 22:	learn: 0.9071730	test: 0.8003674	best: 0.8019542 (18)	total: 9.54s	remaining: 6m 45s
# 23:	learn: 0.9089953	test: 0.8056454	best: 0.8056454 (23)	total: 9.94s	remaining: 6m 44s
# 24:	learn: 0.9102442	test: 0.8047957	best: 0.8056454 (23)	total: 10.3s	remaining: 6m 43s
# 25:	learn: 0.9117775	test: 0.8027533	best: 0.8056454 (23)	total: 10.8s	remaining: 6m 43s
# 26:	learn: 0.9130097	test: 0.8021481	best: 0.8056454 (23)	total: 11.2s	remaining: 6m 42s
# 27:	learn: 0.9153279	test: 0.8012635	best: 0.8056454 (23)	total: 11.6s	remaining: 6m 41s
# 28:	learn: 0.9161618	test: 0.8034414	best: 0.8056454 (23)	total: 12.1s	remaining: 6m 44s
# 29:	learn: 0.9171889	test: 0.8010300	best: 0.8056454 (23)	total: 12.5s	remaining: 6m 43s
# 30:	learn: 0.9177424	test: 0.7995988	best: 0.8056454 (23)	total: 12.8s	remaining: 6m 40s
# 31:	learn: 0.9186695	test: 0.7995779	best: 0.8056454 (23)	total: 13.2s	remaining: 6m 38s
# 32:	learn: 0.9194162	test: 0.7995483	best: 0.8056454 (23)	total: 13.7s	remaining: 6m 40s
# 33:	learn: 0.9208149	test: 0.7979877	best: 0.8056454 (23)	total: 14.1s	remaining: 6m 39s
# 34:	learn: 0.9219980	test: 0.7991478	best: 0.8056454 (23)	total: 14.4s	remaining: 6m 36s
# 35:	learn: 0.9227760	test: 0.7974851	best: 0.8056454 (23)	total: 14.8s	remaining: 6m 35s
# 36:	learn: 0.9231520	test: 0.7960508	best: 0.8056454 (23)	total: 15.2s	remaining: 6m 35s
# 37:	learn: 0.9239705	test: 0.7898590	best: 0.8056454 (23)	total: 15.6s	remaining: 6m 34s
# 38:	learn: 0.9242574	test: 0.7902168	best: 0.8056454 (23)	total: 15.9s	remaining: 6m 32s
# 39:	learn: 0.9248413	test: 0.7895450	best: 0.8056454 (23)	total: 16.3s	remaining: 6m 30s
# 40:	learn: 0.9252082	test: 0.7895405	best: 0.8056454 (23)	total: 16.6s	remaining: 6m 28s
# 41:	learn: 0.9260354	test: 0.7879863	best: 0.8056454 (23)	total: 17s	remaining: 6m 26s
# 42:	learn: 0.9267558	test: 0.7881424	best: 0.8056454 (23)	total: 17.3s	remaining: 6m 24s
# 43:	learn: 0.9273107	test: 0.7851432	best: 0.8056454 (23)	total: 17.7s	remaining: 6m 23s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.8056454215
# bestIteration = 23
#
# Shrink model to first 24 iterations.
# Learning rate set to 0.159788
# 0:	learn: 0.2386485	test: 0.2160142	best: 0.2160142 (0)	total: 559ms	remaining: 9m 18s
# 1:	learn: 0.4117795	test: 0.3637844	best: 0.3637844 (1)	total: 1.1s	remaining: 9m 10s
# 2:	learn: 0.5388238	test: 0.4717476	best: 0.4717476 (2)	total: 1.71s	remaining: 9m 29s
# 3:	learn: 0.6297178	test: 0.5538933	best: 0.5538933 (3)	total: 2.27s	remaining: 9m 24s
# 4:	learn: 0.6957682	test: 0.6202968	best: 0.6202968 (4)	total: 2.73s	remaining: 9m 3s
# 5:	learn: 0.7452637	test: 0.6750528	best: 0.6750528 (5)	total: 3.09s	remaining: 8m 32s
# 6:	learn: 0.7801414	test: 0.7179095	best: 0.7179095 (6)	total: 3.48s	remaining: 8m 13s
# 7:	learn: 0.8057646	test: 0.7471386	best: 0.7471386 (7)	total: 3.96s	remaining: 8m 10s
# 8:	learn: 0.8247050	test: 0.7643089	best: 0.7643089 (8)	total: 4.45s	remaining: 8m 9s
# 9:	learn: 0.8389159	test: 0.7820739	best: 0.7820739 (9)	total: 4.91s	remaining: 8m 5s
# 10:	learn: 0.8507945	test: 0.7994285	best: 0.7994285 (10)	total: 5.29s	remaining: 7m 55s
# 11:	learn: 0.8593416	test: 0.8112440	best: 0.8112440 (11)	total: 5.83s	remaining: 8m
# 12:	learn: 0.8661194	test: 0.8204993	best: 0.8204993 (12)	total: 6.21s	remaining: 7m 51s
# 13:	learn: 0.8738168	test: 0.8176891	best: 0.8204993 (12)	total: 6.72s	remaining: 7m 53s
# 14:	learn: 0.8784003	test: 0.8243447	best: 0.8243447 (14)	total: 7.17s	remaining: 7m 51s
# 15:	learn: 0.8835992	test: 0.8244596	best: 0.8244596 (15)	total: 7.57s	remaining: 7m 45s
# 16:	learn: 0.8860917	test: 0.8297109	best: 0.8297109 (16)	total: 8.01s	remaining: 7m 43s
# 17:	learn: 0.8887461	test: 0.8351670	best: 0.8351670 (17)	total: 8.42s	remaining: 7m 39s
# 18:	learn: 0.8919087	test: 0.8347427	best: 0.8351670 (17)	total: 8.75s	remaining: 7m 31s
# 19:	learn: 0.8943403	test: 0.8368128	best: 0.8368128 (19)	total: 9.19s	remaining: 7m 30s
# 20:	learn: 0.8961481	test: 0.8395213	best: 0.8395213 (20)	total: 9.6s	remaining: 7m 27s
# 21:	learn: 0.8983445	test: 0.8388609	best: 0.8395213 (20)	total: 10s	remaining: 7m 25s
# 22:	learn: 0.8991140	test: 0.8420932	best: 0.8420932 (22)	total: 10.4s	remaining: 7m 22s
# 23:	learn: 0.9006880	test: 0.8442394	best: 0.8442394 (23)	total: 10.8s	remaining: 7m 21s
# 24:	learn: 0.9030236	test: 0.8450552	best: 0.8450552 (24)	total: 11.3s	remaining: 7m 18s
# 25:	learn: 0.9039130	test: 0.8477186	best: 0.8477186 (25)	total: 11.7s	remaining: 7m 16s
# 26:	learn: 0.9049973	test: 0.8484218	best: 0.8484218 (26)	total: 12s	remaining: 7m 13s
# 27:	learn: 0.9063144	test: 0.8488321	best: 0.8488321 (27)	total: 12.4s	remaining: 7m 10s
# 28:	learn: 0.9100351	test: 0.8485344	best: 0.8488321 (27)	total: 12.9s	remaining: 7m 11s
# 29:	learn: 0.9129730	test: 0.8481843	best: 0.8488321 (27)	total: 13.2s	remaining: 7m 7s
# 30:	learn: 0.9137460	test: 0.8483739	best: 0.8488321 (27)	total: 13.6s	remaining: 7m 4s
# 31:	learn: 0.9154434	test: 0.8563032	best: 0.8563032 (31)	total: 13.9s	remaining: 7m 1s
# 32:	learn: 0.9161510	test: 0.8570873	best: 0.8570873 (32)	total: 14.3s	remaining: 6m 59s
# 33:	learn: 0.9175627	test: 0.8586937	best: 0.8586937 (33)	total: 14.7s	remaining: 6m 57s
# 34:	learn: 0.9189678	test: 0.8646292	best: 0.8646292 (34)	total: 15.1s	remaining: 6m 55s
# 35:	learn: 0.9193725	test: 0.8646196	best: 0.8646292 (34)	total: 15.4s	remaining: 6m 51s
# 36:	learn: 0.9201190	test: 0.8642713	best: 0.8646292 (34)	total: 15.8s	remaining: 6m 50s
# 37:	learn: 0.9211428	test: 0.8630727	best: 0.8646292 (34)	total: 16.2s	remaining: 6m 51s
# 38:	learn: 0.9215736	test: 0.8632618	best: 0.8646292 (34)	total: 16.6s	remaining: 6m 49s
# 39:	learn: 0.9220220	test: 0.8625237	best: 0.8646292 (34)	total: 17s	remaining: 6m 48s
# 40:	learn: 0.9228191	test: 0.8613574	best: 0.8646292 (34)	total: 17.4s	remaining: 6m 47s
# 41:	learn: 0.9235020	test: 0.8612153	best: 0.8646292 (34)	total: 17.8s	remaining: 6m 45s
# 42:	learn: 0.9256146	test: 0.8617866	best: 0.8646292 (34)	total: 18.3s	remaining: 6m 47s
# 43:	learn: 0.9259923	test: 0.8617343	best: 0.8646292 (34)	total: 18.7s	remaining: 6m 45s
# 44:	learn: 0.9264195	test: 0.8617366	best: 0.8646292 (34)	total: 19.1s	remaining: 6m 44s
# 45:	learn: 0.9267640	test: 0.8619740	best: 0.8646292 (34)	total: 19.4s	remaining: 6m 41s
# 46:	learn: 0.9270608	test: 0.8621902	best: 0.8646292 (34)	total: 19.6s	remaining: 6m 37s
# 47:	learn: 0.9276564	test: 0.8619779	best: 0.8646292 (34)	total: 19.9s	remaining: 6m 35s
# 48:	learn: 0.9278549	test: 0.8620738	best: 0.8646292 (34)	total: 20.3s	remaining: 6m 34s
# 49:	learn: 0.9280598	test: 0.8620748	best: 0.8646292 (34)	total: 20.7s	remaining: 6m 33s
# 50:	learn: 0.9289651	test: 0.8586547	best: 0.8646292 (34)	total: 21.1s	remaining: 6m 31s
# 51:	learn: 0.9300052	test: 0.8583514	best: 0.8646292 (34)	total: 21.5s	remaining: 6m 31s
# 52:	learn: 0.9305478	test: 0.8584404	best: 0.8646292 (34)	total: 21.9s	remaining: 6m 31s
# 53:	learn: 0.9310876	test: 0.8566047	best: 0.8646292 (34)	total: 22.3s	remaining: 6m 31s
# 54:	learn: 0.9313069	test: 0.8567656	best: 0.8646292 (34)	total: 22.7s	remaining: 6m 30s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.8646292455
# bestIteration = 34
#
# Shrink model to first 35 iterations.
# Learning rate set to 0.159788
# 0:	learn: 0.2454745	test: 0.2153578	best: 0.2153578 (0)	total: 580ms	remaining: 9m 38s
# 1:	learn: 0.4237643	test: 0.3725276	best: 0.3725276 (1)	total: 1.06s	remaining: 8m 47s
# 2:	learn: 0.5544844	test: 0.4953774	best: 0.4953774 (2)	total: 1.66s	remaining: 9m 10s
# 3:	learn: 0.6507458	test: 0.5913717	best: 0.5913717 (3)	total: 2.15s	remaining: 8m 55s
# 4:	learn: 0.7197831	test: 0.6598695	best: 0.6598695 (4)	total: 2.67s	remaining: 8m 50s
# 5:	learn: 0.7678334	test: 0.7087586	best: 0.7087586 (5)	total: 3.12s	remaining: 8m 37s
# 6:	learn: 0.8042977	test: 0.7426525	best: 0.7426525 (6)	total: 3.56s	remaining: 8m 25s
# 7:	learn: 0.8314695	test: 0.7710745	best: 0.7710745 (7)	total: 4.04s	remaining: 8m 20s
# 8:	learn: 0.8516310	test: 0.7936040	best: 0.7936040 (8)	total: 4.51s	remaining: 8m 17s
# 9:	learn: 0.8677002	test: 0.8129085	best: 0.8129085 (9)	total: 4.88s	remaining: 8m 2s
# 10:	learn: 0.8794628	test: 0.8229231	best: 0.8229231 (10)	total: 5.3s	remaining: 7m 56s
# 11:	learn: 0.8892234	test: 0.8357187	best: 0.8357187 (11)	total: 5.74s	remaining: 7m 52s
# 12:	learn: 0.8968193	test: 0.8445622	best: 0.8445622 (12)	total: 6.14s	remaining: 7m 45s
# 13:	learn: 0.9025444	test: 0.8517178	best: 0.8517178 (13)	total: 6.56s	remaining: 7m 41s
# 14:	learn: 0.9072669	test: 0.8561338	best: 0.8561338 (14)	total: 6.96s	remaining: 7m 36s
# 15:	learn: 0.9122534	test: 0.8603249	best: 0.8603249 (15)	total: 7.36s	remaining: 7m 32s
# 16:	learn: 0.9163244	test: 0.8637859	best: 0.8637859 (16)	total: 7.76s	remaining: 7m 28s
# 17:	learn: 0.9189477	test: 0.8673545	best: 0.8673545 (17)	total: 8.21s	remaining: 7m 27s
# 18:	learn: 0.9213665	test: 0.8686626	best: 0.8686626 (18)	total: 8.69s	remaining: 7m 28s
# 19:	learn: 0.9231146	test: 0.8704294	best: 0.8704294 (19)	total: 9.08s	remaining: 7m 25s
# 20:	learn: 0.9245604	test: 0.8736696	best: 0.8736696 (20)	total: 9.47s	remaining: 7m 21s
# 21:	learn: 0.9253704	test: 0.8748837	best: 0.8748837 (21)	total: 9.85s	remaining: 7m 17s
# 22:	learn: 0.9295635	test: 0.8746400	best: 0.8748837 (21)	total: 10.3s	remaining: 7m 15s
# 23:	learn: 0.9305049	test: 0.8756729	best: 0.8756729 (23)	total: 10.6s	remaining: 7m 10s
# 24:	learn: 0.9317908	test: 0.8751786	best: 0.8756729 (23)	total: 11s	remaining: 7m 8s
# 25:	learn: 0.9337187	test: 0.8750552	best: 0.8756729 (23)	total: 11.4s	remaining: 7m 7s
# 26:	learn: 0.9349501	test: 0.8745332	best: 0.8756729 (23)	total: 11.8s	remaining: 7m 3s
# 27:	learn: 0.9363088	test: 0.8748701	best: 0.8756729 (23)	total: 12s	remaining: 6m 57s
# 28:	learn: 0.9369135	test: 0.8748218	best: 0.8756729 (23)	total: 12.4s	remaining: 6m 56s
# 29:	learn: 0.9397768	test: 0.8748911	best: 0.8756729 (23)	total: 12.9s	remaining: 6m 56s
# 30:	learn: 0.9412682	test: 0.8754032	best: 0.8756729 (23)	total: 13.2s	remaining: 6m 54s
# 31:	learn: 0.9417362	test: 0.8766823	best: 0.8766823 (31)	total: 13.6s	remaining: 6m 51s
# 32:	learn: 0.9428983	test: 0.8770689	best: 0.8770689 (32)	total: 13.9s	remaining: 6m 47s
# 33:	learn: 0.9431326	test: 0.8770126	best: 0.8770689 (32)	total: 14.2s	remaining: 6m 44s
# 34:	learn: 0.9434075	test: 0.8769363	best: 0.8770689 (32)	total: 14.6s	remaining: 6m 41s
# 35:	learn: 0.9437321	test: 0.8769364	best: 0.8770689 (32)	total: 14.9s	remaining: 6m 39s
# 36:	learn: 0.9444506	test: 0.8767309	best: 0.8770689 (32)	total: 15.4s	remaining: 6m 39s
# 37:	learn: 0.9449293	test: 0.8768311	best: 0.8770689 (32)	total: 15.7s	remaining: 6m 37s
# 38:	learn: 0.9453447	test: 0.8770292	best: 0.8770689 (32)	total: 16.1s	remaining: 6m 37s
# 39:	learn: 0.9455911	test: 0.8768708	best: 0.8770689 (32)	total: 16.6s	remaining: 6m 38s
# 40:	learn: 0.9457712	test: 0.8768091	best: 0.8770689 (32)	total: 17s	remaining: 6m 37s
# 41:	learn: 0.9459334	test: 0.8767480	best: 0.8770689 (32)	total: 17.4s	remaining: 6m 36s
# 42:	learn: 0.9466252	test: 0.8761269	best: 0.8770689 (32)	total: 17.8s	remaining: 6m 36s
# 43:	learn: 0.9470133	test: 0.8764059	best: 0.8770689 (32)	total: 18.2s	remaining: 6m 34s
# 44:	learn: 0.9472832	test: 0.8765758	best: 0.8770689 (32)	total: 18.5s	remaining: 6m 33s
# 45:	learn: 0.9474520	test: 0.8765033	best: 0.8770689 (32)	total: 18.9s	remaining: 6m 31s
# 46:	learn: 0.9477850	test: 0.8771331	best: 0.8771331 (46)	total: 19.3s	remaining: 6m 31s
# 47:	learn: 0.9481681	test: 0.8746261	best: 0.8771331 (46)	total: 19.7s	remaining: 6m 30s
# 48:	learn: 0.9483698	test: 0.8745580	best: 0.8771331 (46)	total: 20.1s	remaining: 6m 29s
# 49:	learn: 0.9485450	test: 0.8744911	best: 0.8771331 (46)	total: 20.3s	remaining: 6m 26s
# 50:	learn: 0.9487767	test: 0.8746703	best: 0.8771331 (46)	total: 20.9s	remaining: 6m 28s
# 51:	learn: 0.9492529	test: 0.8738124	best: 0.8771331 (46)	total: 21.2s	remaining: 6m 27s
# 52:	learn: 0.9493702	test: 0.8737564	best: 0.8771331 (46)	total: 21.6s	remaining: 6m 25s
# 53:	learn: 0.9495192	test: 0.8736676	best: 0.8771331 (46)	total: 22s	remaining: 6m 25s
# 54:	learn: 0.9496218	test: 0.8735048	best: 0.8771331 (46)	total: 22.4s	remaining: 6m 25s
# 55:	learn: 0.9498826	test: 0.8735459	best: 0.8771331 (46)	total: 22.8s	remaining: 6m 24s
# 56:	learn: 0.9499732	test: 0.8734067	best: 0.8771331 (46)	total: 23.2s	remaining: 6m 24s
# 57:	learn: 0.9505358	test: 0.8730297	best: 0.8771331 (46)	total: 23.7s	remaining: 6m 25s
# 58:	learn: 0.9507441	test: 0.8722384	best: 0.8771331 (46)	total: 24.1s	remaining: 6m 24s
# 59:	learn: 0.9536144	test: 0.8724085	best: 0.8771331 (46)	total: 24.5s	remaining: 6m 24s
# 60:	learn: 0.9539203	test: 0.8719483	best: 0.8771331 (46)	total: 25s	remaining: 6m 24s
# 61:	learn: 0.9562937	test: 0.8719858	best: 0.8771331 (46)	total: 25.4s	remaining: 6m 24s
# 62:	learn: 0.9569872	test: 0.8706511	best: 0.8771331 (46)	total: 25.8s	remaining: 6m 23s
# 63:	learn: 0.9574505	test: 0.8701320	best: 0.8771331 (46)	total: 26.3s	remaining: 6m 24s
# 64:	learn: 0.9576166	test: 0.8697864	best: 0.8771331 (46)	total: 26.7s	remaining: 6m 23s
# 65:	learn: 0.9577320	test: 0.8697887	best: 0.8771331 (46)	total: 27s	remaining: 6m 21s
# 66:	learn: 0.9578924	test: 0.8697253	best: 0.8771331 (46)	total: 27.4s	remaining: 6m 21s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.8771331459
# bestIteration = 46
#
# Shrink model to first 47 iterations.

# %%
pred = np.array(val_preds).mean(axis=0) * 1.2

r2_score(val['PATIENT_ID_COUNT'], pred.clip(min=1).round())
# Out:
# 0.9138139857592371

# %%
test_preds = []
for train_index, test_index in KFold(n_splits=5).split(data):

    model = CatBoostRegressor(
        iterations=150,
        learning_rate=0.159788,
        cat_features=['PATIENT_SEX', 'MKB_CODE', 'ADRES', 'AGE_CATEGORY', 'CODE_TYPE', 'MONTH', 'size', 'CODE_CATEGORY']
    )
    model.fit(
        data.iloc[train_index].drop('PATIENT_ID_COUNT', axis=1), data.iloc[train_index]['PATIENT_ID_COUNT']
    )
    test_preds.append(model.predict(test))
# Out:
# 0:	learn: 56.1064867	total: 307ms	remaining: 45.8s
# 1:	learn: 49.5173269	total: 603ms	remaining: 44.6s
# 2:	learn: 44.0270673	total: 799ms	remaining: 39.1s
# 3:	learn: 39.5478109	total: 1.06s	remaining: 38.8s
# 4:	learn: 35.7918175	total: 1.27s	remaining: 36.9s
# 5:	learn: 32.7613312	total: 1.5s	remaining: 35.9s
# 6:	learn: 30.2970353	total: 1.69s	remaining: 34.5s
# 7:	learn: 28.3712741	total: 1.89s	remaining: 33.6s
# 8:	learn: 26.8520624	total: 2.07s	remaining: 32.4s
# 9:	learn: 25.5582257	total: 2.24s	remaining: 31.4s
# 10:	learn: 24.5334912	total: 2.44s	remaining: 30.9s
# 11:	learn: 23.6348023	total: 2.64s	remaining: 30.4s
# 12:	learn: 22.9150676	total: 2.83s	remaining: 29.8s
# 13:	learn: 22.1726549	total: 3.04s	remaining: 29.5s
# 14:	learn: 21.6774762	total: 3.23s	remaining: 29.1s
# 15:	learn: 21.1855968	total: 3.44s	remaining: 28.8s
# 16:	learn: 20.7193219	total: 3.62s	remaining: 28.3s
# 17:	learn: 20.2458540	total: 3.79s	remaining: 27.8s
# 18:	learn: 19.9222161	total: 3.98s	remaining: 27.5s
# 19:	learn: 19.6617948	total: 4.2s	remaining: 27.3s
# 20:	learn: 19.3934615	total: 4.39s	remaining: 27s
# 21:	learn: 19.1431078	total: 4.59s	remaining: 26.7s
# 22:	learn: 18.9567486	total: 4.75s	remaining: 26.3s
# 23:	learn: 18.8390749	total: 4.95s	remaining: 26s
# 24:	learn: 18.6675893	total: 5.17s	remaining: 25.9s
# 25:	learn: 18.4998292	total: 5.34s	remaining: 25.5s
# 26:	learn: 18.4141325	total: 5.52s	remaining: 25.1s
# 27:	learn: 18.2509828	total: 5.72s	remaining: 24.9s
# 28:	learn: 18.1371606	total: 5.91s	remaining: 24.7s
# 29:	learn: 17.9897779	total: 6.09s	remaining: 24.4s
# 30:	learn: 17.8870390	total: 6.26s	remaining: 24.1s
# 31:	learn: 17.7349838	total: 6.44s	remaining: 23.7s
# 32:	learn: 17.6113559	total: 6.6s	remaining: 23.4s
# 33:	learn: 17.5328234	total: 6.78s	remaining: 23.1s
# 34:	learn: 17.4308338	total: 6.94s	remaining: 22.8s
# 35:	learn: 17.2858297	total: 7.13s	remaining: 22.6s
# 36:	learn: 17.1856778	total: 7.3s	remaining: 22.3s
# 37:	learn: 17.0707218	total: 7.47s	remaining: 22s
# 38:	learn: 16.9452466	total: 7.64s	remaining: 21.7s
# 39:	learn: 16.8511687	total: 7.83s	remaining: 21.5s
# 40:	learn: 16.7170365	total: 7.99s	remaining: 21.2s
# 41:	learn: 16.6131993	total: 8.17s	remaining: 21s
# 42:	learn: 16.5523830	total: 8.34s	remaining: 20.8s
# 43:	learn: 16.4457970	total: 8.52s	remaining: 20.5s
# 44:	learn: 16.3659741	total: 8.69s	remaining: 20.3s
# 45:	learn: 16.2773279	total: 8.87s	remaining: 20s
# 46:	learn: 16.2202510	total: 9.04s	remaining: 19.8s
# 47:	learn: 16.1702089	total: 9.22s	remaining: 19.6s
# 48:	learn: 16.1019643	total: 9.39s	remaining: 19.4s
# 49:	learn: 16.0475550	total: 9.57s	remaining: 19.1s
# 50:	learn: 15.9531536	total: 9.75s	remaining: 18.9s
# 51:	learn: 15.8540722	total: 9.92s	remaining: 18.7s
# 52:	learn: 15.7823550	total: 10.1s	remaining: 18.5s
# 53:	learn: 15.7088011	total: 10.3s	remaining: 18.2s
# 54:	learn: 15.5933364	total: 10.4s	remaining: 18s
# 55:	learn: 15.5405049	total: 10.6s	remaining: 17.8s
# 56:	learn: 15.4873048	total: 10.8s	remaining: 17.6s
# 57:	learn: 15.4134552	total: 11s	remaining: 17.4s
# 58:	learn: 15.3064687	total: 11.1s	remaining: 17.2s
# 59:	learn: 15.2064260	total: 11.3s	remaining: 17s
# 60:	learn: 15.1642872	total: 11.5s	remaining: 16.8s
# 61:	learn: 15.1093369	total: 11.7s	remaining: 16.6s
# 62:	learn: 15.0428853	total: 11.9s	remaining: 16.4s
# 63:	learn: 15.0025974	total: 12s	remaining: 16.2s
# 64:	learn: 14.9255657	total: 12.2s	remaining: 15.9s
# 65:	learn: 14.8351276	total: 12.4s	remaining: 15.7s
# 66:	learn: 14.7665901	total: 12.5s	remaining: 15.5s
# 67:	learn: 14.7207615	total: 12.7s	remaining: 15.3s
# 68:	learn: 14.6463290	total: 12.9s	remaining: 15.1s
# 69:	learn: 14.6178336	total: 13.1s	remaining: 14.9s
# 70:	learn: 14.5264796	total: 13.2s	remaining: 14.7s
# 71:	learn: 14.4879123	total: 13.4s	remaining: 14.6s
# 72:	learn: 14.4403810	total: 13.6s	remaining: 14.4s
# 73:	learn: 14.3622848	total: 13.8s	remaining: 14.2s
# 74:	learn: 14.3373569	total: 14s	remaining: 14s
# 75:	learn: 14.2890376	total: 14.2s	remaining: 13.8s
# 76:	learn: 14.2594687	total: 14.3s	remaining: 13.6s
# 77:	learn: 14.2136484	total: 14.5s	remaining: 13.4s
# 78:	learn: 14.1818230	total: 14.7s	remaining: 13.2s
# 79:	learn: 14.1410621	total: 14.9s	remaining: 13s
# 80:	learn: 14.0882199	total: 15.2s	remaining: 12.9s
# 81:	learn: 14.0441166	total: 15.4s	remaining: 12.7s
# 82:	learn: 14.0075615	total: 15.6s	remaining: 12.6s
# 83:	learn: 13.9784552	total: 15.7s	remaining: 12.4s
# 84:	learn: 13.9340561	total: 15.9s	remaining: 12.2s
# 85:	learn: 13.8526361	total: 16.1s	remaining: 12s
# 86:	learn: 13.8139590	total: 16.3s	remaining: 11.8s
# 87:	learn: 13.7597948	total: 16.4s	remaining: 11.6s
# 88:	learn: 13.7415900	total: 16.6s	remaining: 11.4s
# 89:	learn: 13.7238654	total: 16.8s	remaining: 11.2s
# 90:	learn: 13.6712616	total: 17s	remaining: 11s
# 91:	learn: 13.6243067	total: 17.2s	remaining: 10.8s
# 92:	learn: 13.6013065	total: 17.4s	remaining: 10.7s
# 93:	learn: 13.5310349	total: 17.6s	remaining: 10.5s
# 94:	learn: 13.4610327	total: 17.8s	remaining: 10.3s
# 95:	learn: 13.4406476	total: 18s	remaining: 10.1s
# 96:	learn: 13.3697494	total: 18.2s	remaining: 9.92s
# 97:	learn: 13.3467885	total: 18.3s	remaining: 9.72s
# 98:	learn: 13.3242776	total: 18.5s	remaining: 9.53s
# 99:	learn: 13.2880027	total: 18.7s	remaining: 9.34s
# 100:	learn: 13.2148207	total: 18.9s	remaining: 9.15s
# 101:	learn: 13.1678023	total: 19s	remaining: 8.95s
# 102:	learn: 13.1186222	total: 19.2s	remaining: 8.77s
# 103:	learn: 13.0623005	total: 19.4s	remaining: 8.59s
# 104:	learn: 13.0175628	total: 19.6s	remaining: 8.39s
# 105:	learn: 12.9757717	total: 19.8s	remaining: 8.2s
# 106:	learn: 12.9234975	total: 19.9s	remaining: 8.01s
# 107:	learn: 12.8987228	total: 20.1s	remaining: 7.81s
# 108:	learn: 12.8458693	total: 20.3s	remaining: 7.62s
# 109:	learn: 12.7940737	total: 20.4s	remaining: 7.43s
# 110:	learn: 12.7516267	total: 20.6s	remaining: 7.25s
# 111:	learn: 12.7140376	total: 20.8s	remaining: 7.06s
# 112:	learn: 12.6524834	total: 21s	remaining: 6.87s
# 113:	learn: 12.6247478	total: 21.2s	remaining: 6.68s
# 114:	learn: 12.6029895	total: 21.3s	remaining: 6.49s
# 115:	learn: 12.5761897	total: 21.5s	remaining: 6.3s
# 116:	learn: 12.5409293	total: 21.7s	remaining: 6.11s
# 117:	learn: 12.5163284	total: 21.8s	remaining: 5.92s
# 118:	learn: 12.4753651	total: 22s	remaining: 5.74s
# 119:	learn: 12.4471635	total: 22.2s	remaining: 5.55s
# 120:	learn: 12.4204834	total: 22.4s	remaining: 5.37s
# 121:	learn: 12.3849184	total: 22.6s	remaining: 5.18s
# 122:	learn: 12.3559308	total: 22.7s	remaining: 4.99s
# 123:	learn: 12.3405723	total: 22.9s	remaining: 4.8s
# 124:	learn: 12.3194979	total: 23.1s	remaining: 4.62s
# 125:	learn: 12.3040201	total: 23.3s	remaining: 4.43s
# 126:	learn: 12.2663894	total: 23.4s	remaining: 4.24s
# 127:	learn: 12.2325274	total: 23.6s	remaining: 4.06s
# 128:	learn: 12.2076921	total: 23.8s	remaining: 3.87s
# 129:	learn: 12.1819958	total: 24s	remaining: 3.69s
# 130:	learn: 12.1573460	total: 24.1s	remaining: 3.5s
# 131:	learn: 12.1361908	total: 24.3s	remaining: 3.31s
# 132:	learn: 12.1211946	total: 24.5s	remaining: 3.13s
# 133:	learn: 12.1046929	total: 24.7s	remaining: 2.94s
# 134:	learn: 12.0891269	total: 24.8s	remaining: 2.76s
# 135:	learn: 12.0473549	total: 25s	remaining: 2.57s
# 136:	learn: 12.0174136	total: 25.2s	remaining: 2.39s
# 137:	learn: 12.0019683	total: 25.3s	remaining: 2.2s
# 138:	learn: 11.9769688	total: 25.5s	remaining: 2.02s
# 139:	learn: 11.9434271	total: 25.7s	remaining: 1.83s
# 140:	learn: 11.9136909	total: 25.9s	remaining: 1.65s
# 141:	learn: 11.8867172	total: 26s	remaining: 1.47s
# 142:	learn: 11.8705026	total: 26.2s	remaining: 1.28s
# 143:	learn: 11.8426871	total: 26.4s	remaining: 1.1s
# 144:	learn: 11.8172161	total: 26.5s	remaining: 915ms
# 145:	learn: 11.7801623	total: 26.7s	remaining: 732ms
# 146:	learn: 11.7492678	total: 26.9s	remaining: 548ms
# 147:	learn: 11.7158347	total: 27s	remaining: 365ms
# 148:	learn: 11.6939439	total: 27.2s	remaining: 183ms
# 149:	learn: 11.6744234	total: 27.4s	remaining: 0us
# 0:	learn: 55.6170668	total: 298ms	remaining: 44.5s
# 1:	learn: 49.1102583	total: 589ms	remaining: 43.6s
# 2:	learn: 43.7697965	total: 805ms	remaining: 39.4s
# 3:	learn: 39.4680374	total: 1.1s	remaining: 40.2s
# 4:	learn: 35.8555084	total: 1.28s	remaining: 37.2s
# 5:	learn: 32.9522669	total: 1.55s	remaining: 37.3s
# 6:	learn: 30.6537076	total: 1.73s	remaining: 35.3s
# 7:	learn: 28.7389013	total: 1.91s	remaining: 33.9s
# 8:	learn: 27.2193323	total: 2.12s	remaining: 33.2s
# 9:	learn: 26.0261697	total: 2.32s	remaining: 32.5s
# 10:	learn: 25.0970541	total: 2.5s	remaining: 31.6s
# 11:	learn: 24.2555003	total: 2.74s	remaining: 31.5s
# 12:	learn: 23.6241374	total: 2.93s	remaining: 30.8s
# 13:	learn: 22.9893736	total: 3.1s	remaining: 30.1s
# 14:	learn: 22.5234375	total: 3.28s	remaining: 29.5s
# 15:	learn: 22.1254671	total: 3.48s	remaining: 29.2s
# 16:	learn: 21.7320826	total: 3.66s	remaining: 28.7s
# 17:	learn: 21.4527723	total: 3.84s	remaining: 28.2s
# 18:	learn: 21.1859223	total: 4.01s	remaining: 27.7s
# 19:	learn: 20.9701423	total: 4.2s	remaining: 27.3s
# 20:	learn: 20.6951442	total: 4.39s	remaining: 27s
# 21:	learn: 20.5278692	total: 4.58s	remaining: 26.6s
# 22:	learn: 20.3579758	total: 4.77s	remaining: 26.3s
# 23:	learn: 20.2003926	total: 4.96s	remaining: 26.1s
# 24:	learn: 19.9373431	total: 5.15s	remaining: 25.7s
# 25:	learn: 19.7973835	total: 5.33s	remaining: 25.4s
# 26:	learn: 19.6250537	total: 5.5s	remaining: 25.1s
# 27:	learn: 19.5162329	total: 5.68s	remaining: 24.8s
# 28:	learn: 19.3232725	total: 5.86s	remaining: 24.4s
# 29:	learn: 19.2400451	total: 6.03s	remaining: 24.1s
# 30:	learn: 19.1456644	total: 6.2s	remaining: 23.8s
# 31:	learn: 18.9929554	total: 6.37s	remaining: 23.5s
# 32:	learn: 18.8689704	total: 6.55s	remaining: 23.2s
# 33:	learn: 18.7405803	total: 6.73s	remaining: 23s
# 34:	learn: 18.5462934	total: 6.91s	remaining: 22.7s
# 35:	learn: 18.4447031	total: 7.08s	remaining: 22.4s
# 36:	learn: 18.3871562	total: 7.25s	remaining: 22.1s
# 37:	learn: 18.2904399	total: 7.44s	remaining: 21.9s
# 38:	learn: 18.1954012	total: 7.61s	remaining: 21.7s
# 39:	learn: 18.1376779	total: 7.78s	remaining: 21.4s
# 40:	learn: 18.0770045	total: 8s	remaining: 21.3s
# 41:	learn: 18.0151520	total: 8.18s	remaining: 21s
# 42:	learn: 17.9315208	total: 8.35s	remaining: 20.8s
# 43:	learn: 17.7391870	total: 8.52s	remaining: 20.5s
# 44:	learn: 17.6999924	total: 8.69s	remaining: 20.3s
# 45:	learn: 17.6342547	total: 8.88s	remaining: 20.1s
# 46:	learn: 17.5824688	total: 9.07s	remaining: 19.9s
# 47:	learn: 17.5367080	total: 9.24s	remaining: 19.6s
# 48:	learn: 17.4641116	total: 9.42s	remaining: 19.4s
# 49:	learn: 17.3020417	total: 9.59s	remaining: 19.2s
# 50:	learn: 17.2298898	total: 9.76s	remaining: 18.9s
# 51:	learn: 17.1493245	total: 9.93s	remaining: 18.7s
# 52:	learn: 17.1040085	total: 10.1s	remaining: 18.5s
# 53:	learn: 17.0471023	total: 10.3s	remaining: 18.3s
# 54:	learn: 16.9561390	total: 10.4s	remaining: 18s
# 55:	learn: 16.9224898	total: 10.6s	remaining: 17.8s
# 56:	learn: 16.8709438	total: 10.8s	remaining: 17.6s
# 57:	learn: 16.7980112	total: 11s	remaining: 17.4s
# 58:	learn: 16.7607171	total: 11.1s	remaining: 17.2s
# 59:	learn: 16.6962496	total: 11.3s	remaining: 17s
# 60:	learn: 16.6434005	total: 11.5s	remaining: 16.7s
# 61:	learn: 16.5376719	total: 11.6s	remaining: 16.5s
# 62:	learn: 16.4568109	total: 11.8s	remaining: 16.4s
# 63:	learn: 16.4067294	total: 12s	remaining: 16.2s
# 64:	learn: 16.3627055	total: 12.2s	remaining: 16s
# 65:	learn: 16.2911166	total: 12.4s	remaining: 15.7s
# 66:	learn: 16.2514040	total: 12.5s	remaining: 15.5s
# 67:	learn: 16.1249339	total: 12.7s	remaining: 15.3s
# 68:	learn: 16.0718717	total: 12.9s	remaining: 15.1s
# 69:	learn: 15.9510145	total: 13.1s	remaining: 14.9s
# 70:	learn: 15.8923184	total: 13.3s	remaining: 14.8s
# 71:	learn: 15.8327508	total: 13.4s	remaining: 14.6s
# 72:	learn: 15.7517172	total: 13.6s	remaining: 14.4s
# 73:	learn: 15.7125691	total: 13.8s	remaining: 14.2s
# 74:	learn: 15.6681923	total: 14s	remaining: 14s
# 75:	learn: 15.5923179	total: 14.1s	remaining: 13.8s
# 76:	learn: 15.5494425	total: 14.3s	remaining: 13.6s
# 77:	learn: 15.5045125	total: 14.5s	remaining: 13.4s
# 78:	learn: 15.4682050	total: 14.7s	remaining: 13.2s
# 79:	learn: 15.4100344	total: 14.9s	remaining: 13s
# 80:	learn: 15.3740877	total: 15.1s	remaining: 12.8s
# 81:	learn: 15.3445633	total: 15.2s	remaining: 12.6s
# 82:	learn: 15.3056035	total: 15.4s	remaining: 12.5s
# 83:	learn: 15.2736624	total: 15.6s	remaining: 12.3s
# 84:	learn: 15.2390642	total: 15.8s	remaining: 12.1s
# 85:	learn: 15.1842271	total: 16s	remaining: 11.9s
# 86:	learn: 15.1445267	total: 16.1s	remaining: 11.7s
# 87:	learn: 15.1264093	total: 16.3s	remaining: 11.5s
# 88:	learn: 15.0825863	total: 16.5s	remaining: 11.3s
# 89:	learn: 15.0484823	total: 16.7s	remaining: 11.1s
# 90:	learn: 15.0129655	total: 16.8s	remaining: 10.9s
# 91:	learn: 14.9830898	total: 17s	remaining: 10.7s
# 92:	learn: 14.9382120	total: 17.2s	remaining: 10.5s
# 93:	learn: 14.8932419	total: 17.4s	remaining: 10.3s
# 94:	learn: 14.8552849	total: 17.5s	remaining: 10.2s
# 95:	learn: 14.8093909	total: 17.7s	remaining: 9.96s
# 96:	learn: 14.7606879	total: 17.9s	remaining: 9.77s
# 97:	learn: 14.7268089	total: 18s	remaining: 9.57s
# 98:	learn: 14.6954809	total: 18.2s	remaining: 9.38s
# 99:	learn: 14.6621773	total: 18.4s	remaining: 9.2s
# 100:	learn: 14.6215856	total: 18.6s	remaining: 9.04s
# 101:	learn: 14.5807195	total: 18.8s	remaining: 8.86s
# 102:	learn: 14.5423677	total: 19s	remaining: 8.68s
# 103:	learn: 14.5271771	total: 19.2s	remaining: 8.49s
# 104:	learn: 14.4790255	total: 19.4s	remaining: 8.29s
# 105:	learn: 14.3780738	total: 19.5s	remaining: 8.11s
# 106:	learn: 14.3459295	total: 19.7s	remaining: 7.91s
# 107:	learn: 14.2962943	total: 19.9s	remaining: 7.73s
# 108:	learn: 14.2727683	total: 20.1s	remaining: 7.55s
# 109:	learn: 14.2539923	total: 20.2s	remaining: 7.36s
# 110:	learn: 14.2248921	total: 20.4s	remaining: 7.17s
# 111:	learn: 14.2057371	total: 20.6s	remaining: 6.99s
# 112:	learn: 14.1868843	total: 20.8s	remaining: 6.82s
# 113:	learn: 14.1465099	total: 21s	remaining: 6.64s
# 114:	learn: 14.0992586	total: 21.2s	remaining: 6.45s
# 115:	learn: 14.0623013	total: 21.4s	remaining: 6.27s
# 116:	learn: 14.0278396	total: 21.6s	remaining: 6.08s
# 117:	learn: 13.9972281	total: 21.8s	remaining: 5.9s
# 118:	learn: 13.9521235	total: 22s	remaining: 5.72s
# 119:	learn: 13.9082378	total: 22.2s	remaining: 5.54s
# 120:	learn: 13.8749473	total: 22.4s	remaining: 5.37s
# 121:	learn: 13.8551169	total: 22.6s	remaining: 5.19s
# 122:	learn: 13.8197534	total: 22.8s	remaining: 5s
# 123:	learn: 13.7947094	total: 23s	remaining: 4.82s
# 124:	learn: 13.7698040	total: 23.2s	remaining: 4.63s
# 125:	learn: 13.7456959	total: 23.3s	remaining: 4.44s
# 126:	learn: 13.7203266	total: 23.5s	remaining: 4.26s
# 127:	learn: 13.7079670	total: 23.7s	remaining: 4.07s
# 128:	learn: 13.6798264	total: 23.9s	remaining: 3.88s
# 129:	learn: 13.6529704	total: 24.1s	remaining: 3.7s
# 130:	learn: 13.6335003	total: 24.2s	remaining: 3.51s
# 131:	learn: 13.6037434	total: 24.4s	remaining: 3.33s
# 132:	learn: 13.5675063	total: 24.6s	remaining: 3.15s
# 133:	learn: 13.5379246	total: 24.8s	remaining: 2.96s
# 134:	learn: 13.5033768	total: 25s	remaining: 2.78s
# 135:	learn: 13.4805710	total: 25.2s	remaining: 2.59s
# 136:	learn: 13.4649952	total: 25.4s	remaining: 2.41s
# 137:	learn: 13.4425082	total: 25.5s	remaining: 2.22s
# 138:	learn: 13.3869318	total: 25.7s	remaining: 2.04s
# 139:	learn: 13.3372532	total: 25.9s	remaining: 1.85s
# 140:	learn: 13.3133305	total: 26.1s	remaining: 1.66s
# 141:	learn: 13.3026251	total: 26.2s	remaining: 1.48s
# 142:	learn: 13.2848502	total: 26.4s	remaining: 1.29s
# 143:	learn: 13.2609663	total: 26.6s	remaining: 1.11s
# 144:	learn: 13.2489455	total: 26.7s	remaining: 922ms
# 145:	learn: 13.2283488	total: 26.9s	remaining: 737ms
# 146:	learn: 13.2150885	total: 27.1s	remaining: 553ms
# 147:	learn: 13.1892962	total: 27.3s	remaining: 369ms
# 148:	learn: 13.1742919	total: 27.4s	remaining: 184ms
# 149:	learn: 13.1522470	total: 27.6s	remaining: 0us
# 0:	learn: 55.6237617	total: 334ms	remaining: 49.8s
# 1:	learn: 49.1430105	total: 625ms	remaining: 46.2s
# 2:	learn: 43.7759253	total: 824ms	remaining: 40.4s
# 3:	learn: 39.4524437	total: 1.12s	remaining: 40.8s
# 4:	learn: 35.8514398	total: 1.34s	remaining: 38.9s
# 5:	learn: 32.9613483	total: 1.57s	remaining: 37.6s
# 6:	learn: 30.6260793	total: 1.76s	remaining: 36s
# 7:	learn: 28.8238232	total: 1.95s	remaining: 34.6s
# 8:	learn: 27.4082890	total: 2.17s	remaining: 33.9s
# 9:	learn: 26.3512322	total: 2.39s	remaining: 33.5s
# 10:	learn: 25.2852223	total: 2.56s	remaining: 32.4s
# 11:	learn: 24.5073198	total: 2.76s	remaining: 31.7s
# 12:	learn: 23.8685891	total: 2.96s	remaining: 31.2s
# 13:	learn: 23.3350823	total: 3.14s	remaining: 30.5s
# 14:	learn: 22.8838415	total: 3.34s	remaining: 30s
# 15:	learn: 22.4996216	total: 3.52s	remaining: 29.5s
# 16:	learn: 22.0657191	total: 3.71s	remaining: 29s
# 17:	learn: 21.7924191	total: 3.89s	remaining: 28.5s
# 18:	learn: 21.4668841	total: 4.06s	remaining: 28s
# 19:	learn: 21.1245193	total: 4.24s	remaining: 27.6s
# 20:	learn: 20.8083977	total: 4.43s	remaining: 27.2s
# 21:	learn: 20.6786358	total: 4.61s	remaining: 26.8s
# 22:	learn: 20.4982507	total: 4.78s	remaining: 26.4s
# 23:	learn: 20.2334445	total: 4.97s	remaining: 26.1s
# 24:	learn: 20.0327453	total: 5.17s	remaining: 25.8s
# 25:	learn: 19.8972680	total: 5.36s	remaining: 25.6s
# 26:	learn: 19.7124130	total: 5.57s	remaining: 25.4s
# 27:	learn: 19.5663969	total: 5.74s	remaining: 25s
# 28:	learn: 19.4316297	total: 5.92s	remaining: 24.7s
# 29:	learn: 19.3133135	total: 6.09s	remaining: 24.4s
# 30:	learn: 19.2347553	total: 6.26s	remaining: 24s
# 31:	learn: 19.0967976	total: 6.43s	remaining: 23.7s
# 32:	learn: 18.9871962	total: 6.61s	remaining: 23.4s
# 33:	learn: 18.9327232	total: 6.78s	remaining: 23.1s
# 34:	learn: 18.8483795	total: 6.95s	remaining: 22.8s
# 35:	learn: 18.7730323	total: 7.13s	remaining: 22.6s
# 36:	learn: 18.7060926	total: 7.36s	remaining: 22.5s
# 37:	learn: 18.5736542	total: 7.53s	remaining: 22.2s
# 38:	learn: 18.5325536	total: 7.71s	remaining: 21.9s
# 39:	learn: 18.4152598	total: 7.9s	remaining: 21.7s
# 40:	learn: 18.3169524	total: 8.12s	remaining: 21.6s
# 41:	learn: 18.2607018	total: 8.3s	remaining: 21.3s
# 42:	learn: 18.2102968	total: 8.47s	remaining: 21.1s
# 43:	learn: 18.1659804	total: 8.66s	remaining: 20.9s
# 44:	learn: 18.0523343	total: 8.84s	remaining: 20.6s
# 45:	learn: 17.9638594	total: 9.04s	remaining: 20.4s
# 46:	learn: 17.9023598	total: 9.28s	remaining: 20.3s
# 47:	learn: 17.8387287	total: 9.52s	remaining: 20.2s
# 48:	learn: 17.7937938	total: 9.74s	remaining: 20.1s
# 49:	learn: 17.6910965	total: 9.99s	remaining: 20s
# 50:	learn: 17.6131795	total: 10.2s	remaining: 19.8s
# 51:	learn: 17.5439591	total: 10.4s	remaining: 19.5s
# 52:	learn: 17.4577300	total: 10.6s	remaining: 19.3s
# 53:	learn: 17.4056118	total: 10.8s	remaining: 19.2s
# 54:	learn: 17.3855092	total: 11s	remaining: 19s
# 55:	learn: 17.3345748	total: 11.2s	remaining: 18.8s
# 56:	learn: 17.2479487	total: 11.4s	remaining: 18.6s
# 57:	learn: 17.1305354	total: 11.6s	remaining: 18.3s
# 58:	learn: 17.0728748	total: 11.7s	remaining: 18.1s
# 59:	learn: 16.9599541	total: 11.9s	remaining: 17.9s
# 60:	learn: 16.8770165	total: 12.1s	remaining: 17.6s
# 61:	learn: 16.8116574	total: 12.2s	remaining: 17.4s
# 62:	learn: 16.7394930	total: 12.4s	remaining: 17.2s
# 63:	learn: 16.6558369	total: 12.6s	remaining: 17s
# 64:	learn: 16.6042016	total: 12.8s	remaining: 16.8s
# 65:	learn: 16.5656485	total: 13.1s	remaining: 16.6s
# 66:	learn: 16.4841075	total: 13.3s	remaining: 16.4s
# 67:	learn: 16.4413343	total: 13.5s	remaining: 16.2s
# 68:	learn: 16.4044532	total: 13.6s	remaining: 16s
# 69:	learn: 16.3419005	total: 13.8s	remaining: 15.8s
# 70:	learn: 16.2980774	total: 14s	remaining: 15.6s
# 71:	learn: 16.2627645	total: 14.2s	remaining: 15.4s
# 72:	learn: 16.2221752	total: 14.4s	remaining: 15.2s
# 73:	learn: 16.1874736	total: 14.5s	remaining: 14.9s
# 74:	learn: 16.1296230	total: 14.7s	remaining: 14.7s
# 75:	learn: 16.0814356	total: 14.9s	remaining: 14.5s
# 76:	learn: 16.0126855	total: 15.1s	remaining: 14.3s
# 77:	learn: 15.9330180	total: 15.2s	remaining: 14.1s
# 78:	learn: 15.9042017	total: 15.4s	remaining: 13.9s
# 79:	learn: 15.8252796	total: 15.6s	remaining: 13.6s
# 80:	learn: 15.7605937	total: 15.8s	remaining: 13.4s
# 81:	learn: 15.7241208	total: 15.9s	remaining: 13.2s
# 82:	learn: 15.6819664	total: 16.1s	remaining: 13s
# 83:	learn: 15.6150437	total: 16.3s	remaining: 12.8s
# 84:	learn: 15.5945705	total: 16.5s	remaining: 12.6s
# 85:	learn: 15.5319066	total: 16.7s	remaining: 12.4s
# 86:	learn: 15.5023098	total: 16.8s	remaining: 12.2s
# 87:	learn: 15.4685835	total: 17s	remaining: 12s
# 88:	learn: 15.4173053	total: 17.2s	remaining: 11.8s
# 89:	learn: 15.3719106	total: 17.4s	remaining: 11.6s
# 90:	learn: 15.3080251	total: 17.5s	remaining: 11.4s
# 91:	learn: 15.2611744	total: 17.7s	remaining: 11.2s
# 92:	learn: 15.1955913	total: 17.9s	remaining: 11s
# 93:	learn: 15.1511872	total: 18.1s	remaining: 10.8s
# 94:	learn: 15.1117832	total: 18.2s	remaining: 10.6s
# 95:	learn: 15.0722156	total: 18.4s	remaining: 10.4s
# 96:	learn: 15.0412730	total: 18.6s	remaining: 10.2s
# 97:	learn: 14.9813097	total: 18.8s	remaining: 9.96s
# 98:	learn: 14.9651949	total: 19s	remaining: 9.76s
# 99:	learn: 14.9316816	total: 19.1s	remaining: 9.57s
# 100:	learn: 14.8979804	total: 19.3s	remaining: 9.37s
# 101:	learn: 14.8533818	total: 19.5s	remaining: 9.17s
# 102:	learn: 14.8263462	total: 19.6s	remaining: 8.97s
# 103:	learn: 14.7936611	total: 19.8s	remaining: 8.77s
# 104:	learn: 14.7649299	total: 20s	remaining: 8.57s
# 105:	learn: 14.7218221	total: 20.2s	remaining: 8.37s
# 106:	learn: 14.6548952	total: 20.3s	remaining: 8.18s
# 107:	learn: 14.6298347	total: 20.5s	remaining: 7.98s
# 108:	learn: 14.5945832	total: 20.7s	remaining: 7.79s
# 109:	learn: 14.5604888	total: 20.9s	remaining: 7.59s
# 110:	learn: 14.5145171	total: 21s	remaining: 7.39s
# 111:	learn: 14.4691559	total: 21.2s	remaining: 7.19s
# 112:	learn: 14.4361872	total: 21.4s	remaining: 7s
# 113:	learn: 14.4041296	total: 21.6s	remaining: 6.81s
# 114:	learn: 14.3636845	total: 21.7s	remaining: 6.61s
# 115:	learn: 14.3347290	total: 21.9s	remaining: 6.42s
# 116:	learn: 14.3144975	total: 22.1s	remaining: 6.22s
# 117:	learn: 14.2968413	total: 22.3s	remaining: 6.03s
# 118:	learn: 14.2649255	total: 22.4s	remaining: 5.84s
# 119:	learn: 14.2510563	total: 22.6s	remaining: 5.66s
# 120:	learn: 14.2397265	total: 22.8s	remaining: 5.46s
# 121:	learn: 14.2057054	total: 23s	remaining: 5.27s
# 122:	learn: 14.1871696	total: 23.1s	remaining: 5.08s
# 123:	learn: 14.1777568	total: 23.3s	remaining: 4.89s
# 124:	learn: 14.1509754	total: 23.5s	remaining: 4.7s
# 125:	learn: 14.1183871	total: 23.7s	remaining: 4.51s
# 126:	learn: 14.0917598	total: 23.8s	remaining: 4.32s
# 127:	learn: 14.0666420	total: 24s	remaining: 4.13s
# 128:	learn: 14.0478079	total: 24.2s	remaining: 3.94s
# 129:	learn: 14.0349551	total: 24.4s	remaining: 3.75s
# 130:	learn: 14.0136611	total: 24.5s	remaining: 3.56s
# 131:	learn: 13.9954126	total: 24.7s	remaining: 3.37s
# 132:	learn: 13.9535250	total: 24.9s	remaining: 3.18s
# 133:	learn: 13.9255907	total: 25.1s	remaining: 2.99s
# 134:	learn: 13.9002406	total: 25.2s	remaining: 2.8s
# 135:	learn: 13.8630974	total: 25.4s	remaining: 2.62s
# 136:	learn: 13.8058507	total: 25.6s	remaining: 2.43s
# 137:	learn: 13.7739656	total: 25.8s	remaining: 2.24s
# 138:	learn: 13.7265630	total: 25.9s	remaining: 2.05s
# 139:	learn: 13.6985075	total: 26.1s	remaining: 1.86s
# 140:	learn: 13.6669239	total: 26.3s	remaining: 1.68s
# 141:	learn: 13.6365816	total: 26.5s	remaining: 1.49s
# 142:	learn: 13.6199670	total: 26.6s	remaining: 1.3s
# 143:	learn: 13.5668467	total: 26.8s	remaining: 1.12s
# 144:	learn: 13.5474573	total: 27s	remaining: 930ms
# 145:	learn: 13.5210769	total: 27.1s	remaining: 743ms
# 146:	learn: 13.4989030	total: 27.3s	remaining: 557ms
# 147:	learn: 13.4671482	total: 27.5s	remaining: 371ms
# 148:	learn: 13.4320767	total: 27.7s	remaining: 186ms
# 149:	learn: 13.4123599	total: 27.8s	remaining: 0us
# 0:	learn: 54.4307034	total: 364ms	remaining: 54.2s
# 1:	learn: 48.0050071	total: 636ms	remaining: 47.1s
# 2:	learn: 42.6392981	total: 910ms	remaining: 44.6s
# 3:	learn: 38.2635386	total: 1.19s	remaining: 43.5s
# 4:	learn: 34.5430337	total: 1.4s	remaining: 40.5s
# 5:	learn: 31.6259096	total: 1.6s	remaining: 38.4s
# 6:	learn: 29.1094094	total: 1.81s	remaining: 37s
# 7:	learn: 27.1235267	total: 2.01s	remaining: 35.6s
# 8:	learn: 25.5101577	total: 2.19s	remaining: 34.3s
# 9:	learn: 24.2436550	total: 2.39s	remaining: 33.5s
# 10:	learn: 23.1967992	total: 2.62s	remaining: 33.1s
# 11:	learn: 22.3123759	total: 2.8s	remaining: 32.2s
# 12:	learn: 21.5700296	total: 3.02s	remaining: 31.9s
# 13:	learn: 20.9544332	total: 3.23s	remaining: 31.4s
# 14:	learn: 20.4035640	total: 3.44s	remaining: 31s
# 15:	learn: 19.9742730	total: 3.64s	remaining: 30.5s
# 16:	learn: 19.5838761	total: 3.85s	remaining: 30.1s
# 17:	learn: 19.2688122	total: 4.03s	remaining: 29.5s
# 18:	learn: 18.9816419	total: 4.21s	remaining: 29.1s
# 19:	learn: 18.6880817	total: 4.38s	remaining: 28.5s
# 20:	learn: 18.5035915	total: 4.61s	remaining: 28.3s
# 21:	learn: 18.2705339	total: 4.79s	remaining: 27.9s
# 22:	learn: 18.0447277	total: 4.97s	remaining: 27.4s
# 23:	learn: 17.8664872	total: 5.17s	remaining: 27.2s
# 24:	learn: 17.6342179	total: 5.35s	remaining: 26.7s
# 25:	learn: 17.5193394	total: 5.53s	remaining: 26.4s
# 26:	learn: 17.3435468	total: 5.7s	remaining: 26s
# 27:	learn: 17.2465600	total: 5.88s	remaining: 25.6s
# 28:	learn: 17.1281767	total: 6.06s	remaining: 25.3s
# 29:	learn: 17.0054159	total: 6.25s	remaining: 25s
# 30:	learn: 16.8372255	total: 6.45s	remaining: 24.8s
# 31:	learn: 16.7676326	total: 6.63s	remaining: 24.4s
# 32:	learn: 16.6785590	total: 6.81s	remaining: 24.1s
# 33:	learn: 16.6029867	total: 6.99s	remaining: 23.8s
# 34:	learn: 16.6029320	total: 7.12s	remaining: 23.4s
# 35:	learn: 16.4421571	total: 7.31s	remaining: 23.1s
# 36:	learn: 16.3285798	total: 7.48s	remaining: 22.9s
# 37:	learn: 16.2622733	total: 7.66s	remaining: 22.6s
# 38:	learn: 16.1927371	total: 7.84s	remaining: 22.3s
# 39:	learn: 16.1927357	total: 7.97s	remaining: 21.9s
# 40:	learn: 16.1921930	total: 8.08s	remaining: 21.5s
# 41:	learn: 16.1909953	total: 8.26s	remaining: 21.2s
# 42:	learn: 16.0552128	total: 8.44s	remaining: 21s
# 43:	learn: 15.9720976	total: 8.62s	remaining: 20.8s
# 44:	learn: 15.9202200	total: 8.8s	remaining: 20.5s
# 45:	learn: 15.8618054	total: 8.98s	remaining: 20.3s
# 46:	learn: 15.8018511	total: 9.16s	remaining: 20.1s
# 47:	learn: 15.8015458	total: 9.27s	remaining: 19.7s
# 48:	learn: 15.7432484	total: 9.44s	remaining: 19.5s
# 49:	learn: 15.7431899	total: 9.62s	remaining: 19.2s
# 50:	learn: 15.6806699	total: 9.79s	remaining: 19s
# 51:	learn: 15.6805915	total: 9.95s	remaining: 18.8s
# 52:	learn: 15.5592130	total: 10.1s	remaining: 18.5s
# 53:	learn: 15.5052967	total: 10.3s	remaining: 18.4s
# 54:	learn: 15.4409106	total: 10.5s	remaining: 18.1s
# 55:	learn: 15.3908552	total: 10.7s	remaining: 17.9s
# 56:	learn: 15.3803892	total: 10.8s	remaining: 17.7s
# 57:	learn: 15.3505376	total: 11s	remaining: 17.5s
# 58:	learn: 15.3104387	total: 11.2s	remaining: 17.3s
# 59:	learn: 15.3103633	total: 11.4s	remaining: 17.1s
# 60:	learn: 15.2561107	total: 11.5s	remaining: 16.8s
# 61:	learn: 15.1976166	total: 11.7s	remaining: 16.6s
# 62:	learn: 15.1509227	total: 11.9s	remaining: 16.4s
# 63:	learn: 15.0896141	total: 12.1s	remaining: 16.2s
# 64:	learn: 15.0264542	total: 12.3s	remaining: 16s
# 65:	learn: 14.9903344	total: 12.4s	remaining: 15.8s
# 66:	learn: 14.9170227	total: 12.6s	remaining: 15.6s
# 67:	learn: 14.8635973	total: 12.8s	remaining: 15.4s
# 68:	learn: 14.8352857	total: 13s	remaining: 15.3s
# 69:	learn: 14.6007644	total: 13.2s	remaining: 15.1s
# 70:	learn: 14.5280045	total: 13.4s	remaining: 14.9s
# 71:	learn: 14.4536588	total: 13.6s	remaining: 14.7s
# 72:	learn: 14.4275359	total: 13.7s	remaining: 14.5s
# 73:	learn: 14.3251699	total: 13.9s	remaining: 14.3s
# 74:	learn: 14.3020097	total: 14.1s	remaining: 14.1s
# 75:	learn: 14.3019820	total: 14.3s	remaining: 13.9s
# 76:	learn: 14.2791925	total: 14.4s	remaining: 13.7s
# 77:	learn: 14.2366774	total: 14.6s	remaining: 13.5s
# 78:	learn: 14.1767428	total: 14.8s	remaining: 13.3s
# 79:	learn: 14.1258038	total: 15s	remaining: 13.1s
# 80:	learn: 14.1257934	total: 15.1s	remaining: 12.9s
# 81:	learn: 14.1171657	total: 15.3s	remaining: 12.7s
# 82:	learn: 14.0976268	total: 15.5s	remaining: 12.5s
# 83:	learn: 14.0421920	total: 15.6s	remaining: 12.3s
# 84:	learn: 13.9926274	total: 15.8s	remaining: 12.1s
# 85:	learn: 13.9671929	total: 16s	remaining: 11.9s
# 86:	learn: 13.9312652	total: 16.3s	remaining: 11.8s
# 87:	learn: 13.8897497	total: 16.5s	remaining: 11.6s
# 88:	learn: 13.8552416	total: 16.7s	remaining: 11.4s
# 89:	learn: 13.8482709	total: 16.9s	remaining: 11.2s
# 90:	learn: 13.7876572	total: 17s	remaining: 11s
# 91:	learn: 13.7405295	total: 17.2s	remaining: 10.8s
# 92:	learn: 13.7017311	total: 17.4s	remaining: 10.7s
# 93:	learn: 13.6470183	total: 17.6s	remaining: 10.5s
# 94:	learn: 13.6341448	total: 17.8s	remaining: 10.3s
# 95:	learn: 13.5954519	total: 17.9s	remaining: 10.1s
# 96:	learn: 13.5348680	total: 18.1s	remaining: 9.89s
# 97:	learn: 13.5255317	total: 18.3s	remaining: 9.71s
# 98:	learn: 13.4824384	total: 18.5s	remaining: 9.52s
# 99:	learn: 13.4541325	total: 18.7s	remaining: 9.33s
# 100:	learn: 13.2837891	total: 18.8s	remaining: 9.14s
# 101:	learn: 13.2427350	total: 19s	remaining: 8.95s
# 102:	learn: 13.1990343	total: 19.2s	remaining: 8.76s
# 103:	learn: 13.1579536	total: 19.4s	remaining: 8.58s
# 104:	learn: 13.1179137	total: 19.6s	remaining: 8.4s
# 105:	learn: 13.0923686	total: 19.8s	remaining: 8.22s
# 106:	learn: 13.0560669	total: 20s	remaining: 8.03s
# 107:	learn: 13.0367598	total: 20.1s	remaining: 7.83s
# 108:	learn: 13.0061232	total: 20.3s	remaining: 7.65s
# 109:	learn: 12.9834725	total: 20.5s	remaining: 7.46s
# 110:	learn: 12.9737610	total: 20.7s	remaining: 7.27s
# 111:	learn: 12.9519506	total: 20.9s	remaining: 7.08s
# 112:	learn: 12.9385227	total: 21.1s	remaining: 6.89s
# 113:	learn: 12.9039542	total: 21.2s	remaining: 6.7s
# 114:	learn: 12.8602759	total: 21.4s	remaining: 6.52s
# 115:	learn: 12.7231402	total: 21.6s	remaining: 6.33s
# 116:	learn: 12.7122520	total: 21.8s	remaining: 6.14s
# 117:	learn: 12.6655149	total: 21.9s	remaining: 5.95s
# 118:	learn: 12.6564872	total: 22.1s	remaining: 5.76s
# 119:	learn: 12.6157150	total: 22.3s	remaining: 5.58s
# 120:	learn: 12.5417515	total: 22.5s	remaining: 5.4s
# 121:	learn: 12.5094607	total: 22.8s	remaining: 5.23s
# 122:	learn: 12.4664286	total: 22.9s	remaining: 5.04s
# 123:	learn: 12.4300521	total: 23.2s	remaining: 4.86s
# 124:	learn: 12.4104988	total: 23.4s	remaining: 4.67s
# 125:	learn: 12.3851597	total: 23.6s	remaining: 4.49s
# 126:	learn: 12.3327015	total: 23.7s	remaining: 4.3s
# 127:	learn: 12.3129465	total: 23.9s	remaining: 4.11s
# 128:	learn: 12.2934042	total: 24.1s	remaining: 3.92s
# 129:	learn: 12.2602627	total: 24.3s	remaining: 3.73s
# 130:	learn: 12.2525907	total: 24.5s	remaining: 3.55s
# 131:	learn: 12.2290027	total: 24.6s	remaining: 3.36s
# 132:	learn: 12.2147816	total: 24.8s	remaining: 3.17s
# 133:	learn: 12.1801632	total: 25s	remaining: 2.99s
# 134:	learn: 12.1620368	total: 25.2s	remaining: 2.8s
# 135:	learn: 12.1409366	total: 25.4s	remaining: 2.62s
# 136:	learn: 12.1089671	total: 25.6s	remaining: 2.43s
# 137:	learn: 12.0951767	total: 25.8s	remaining: 2.24s
# 138:	learn: 12.0828880	total: 26s	remaining: 2.05s
# 139:	learn: 12.0613073	total: 26.1s	remaining: 1.87s
# 140:	learn: 12.0403380	total: 26.3s	remaining: 1.68s
# 141:	learn: 12.0135955	total: 26.5s	remaining: 1.49s
# 142:	learn: 11.9928525	total: 26.7s	remaining: 1.3s
# 143:	learn: 11.9596723	total: 26.9s	remaining: 1.12s
# 144:	learn: 11.9363816	total: 27.1s	remaining: 933ms
# 145:	learn: 11.7952306	total: 27.2s	remaining: 747ms
# 146:	learn: 11.7658488	total: 27.5s	remaining: 560ms
# 147:	learn: 11.7473879	total: 27.6s	remaining: 373ms
# 148:	learn: 11.7350432	total: 27.8s	remaining: 187ms
# 149:	learn: 11.6922679	total: 28s	remaining: 0us
# 0:	learn: 40.9540089	total: 378ms	remaining: 56.3s
# 1:	learn: 35.8891775	total: 569ms	remaining: 42.1s
# 2:	learn: 31.7068658	total: 849ms	remaining: 41.6s
# 3:	learn: 28.4073068	total: 1.1s	remaining: 40.3s
# 4:	learn: 25.7138014	total: 1.34s	remaining: 38.9s
# 5:	learn: 23.5392584	total: 1.56s	remaining: 37.4s
# 6:	learn: 21.8295179	total: 1.74s	remaining: 35.6s
# 7:	learn: 20.4086707	total: 1.93s	remaining: 34.3s
# 8:	learn: 19.3353436	total: 2.12s	remaining: 33.2s
# 9:	learn: 18.4339008	total: 2.35s	remaining: 32.9s
# 10:	learn: 17.7146980	total: 2.55s	remaining: 32.2s
# 11:	learn: 17.1286236	total: 2.82s	remaining: 32.5s
# 12:	learn: 16.6456404	total: 3.01s	remaining: 31.8s
# 13:	learn: 16.2974756	total: 3.21s	remaining: 31.2s
# 14:	learn: 15.9618550	total: 3.39s	remaining: 30.5s
# 15:	learn: 15.7266748	total: 3.57s	remaining: 29.9s
# 16:	learn: 15.4668510	total: 3.76s	remaining: 29.4s
# 17:	learn: 15.2739016	total: 3.96s	remaining: 29s
# 18:	learn: 15.0718765	total: 4.13s	remaining: 28.4s
# 19:	learn: 14.9246921	total: 4.3s	remaining: 28s
# 20:	learn: 14.7706547	total: 4.5s	remaining: 27.6s
# 21:	learn: 14.6295595	total: 4.68s	remaining: 27.2s
# 22:	learn: 14.5247410	total: 4.86s	remaining: 26.8s
# 23:	learn: 14.4043298	total: 5.05s	remaining: 26.5s
# 24:	learn: 14.2954076	total: 5.23s	remaining: 26.1s
# 25:	learn: 14.2003734	total: 5.4s	remaining: 25.8s
# 26:	learn: 14.1257627	total: 5.58s	remaining: 25.4s
# 27:	learn: 14.0540708	total: 5.77s	remaining: 25.1s
# 28:	learn: 13.9872874	total: 5.98s	remaining: 24.9s
# 29:	learn: 13.9056666	total: 6.16s	remaining: 24.6s
# 30:	learn: 13.8410862	total: 6.33s	remaining: 24.3s
# 31:	learn: 13.7766445	total: 6.51s	remaining: 24s
# 32:	learn: 13.7234804	total: 6.69s	remaining: 23.7s
# 33:	learn: 13.6646460	total: 6.86s	remaining: 23.4s
# 34:	learn: 13.6167132	total: 7.04s	remaining: 23.1s
# 35:	learn: 13.5433063	total: 7.22s	remaining: 22.9s
# 36:	learn: 13.4943017	total: 7.41s	remaining: 22.6s
# 37:	learn: 13.4386598	total: 7.58s	remaining: 22.4s
# 38:	learn: 13.3854287	total: 7.76s	remaining: 22.1s
# 39:	learn: 13.3469933	total: 7.94s	remaining: 21.8s
# 40:	learn: 13.2956066	total: 8.12s	remaining: 21.6s
# 41:	learn: 13.2552670	total: 8.3s	remaining: 21.3s
# 42:	learn: 13.2090674	total: 8.53s	remaining: 21.2s
# 43:	learn: 13.1746182	total: 8.73s	remaining: 21s
# 44:	learn: 13.1517233	total: 8.94s	remaining: 20.9s
# 45:	learn: 12.9656081	total: 9.14s	remaining: 20.7s
# 46:	learn: 12.8947504	total: 9.32s	remaining: 20.4s
# 47:	learn: 12.8639306	total: 9.48s	remaining: 20.1s
# 48:	learn: 12.8015812	total: 9.67s	remaining: 19.9s
# 49:	learn: 12.7625378	total: 9.85s	remaining: 19.7s
# 50:	learn: 12.6159648	total: 10s	remaining: 19.5s
# 51:	learn: 12.5594259	total: 10.2s	remaining: 19.2s
# 52:	learn: 12.5110753	total: 10.4s	remaining: 19s
# 53:	learn: 12.4460377	total: 10.6s	remaining: 18.9s
# 54:	learn: 12.4032490	total: 10.8s	remaining: 18.7s
# 55:	learn: 12.3454084	total: 11s	remaining: 18.4s
# 56:	learn: 12.3106813	total: 11.2s	remaining: 18.3s
# 57:	learn: 12.2614294	total: 11.4s	remaining: 18.1s
# 58:	learn: 12.1577475	total: 11.6s	remaining: 17.9s
# 59:	learn: 12.1280230	total: 11.8s	remaining: 17.7s
# 60:	learn: 12.0838340	total: 12s	remaining: 17.5s
# 61:	learn: 12.0596500	total: 12.2s	remaining: 17.3s
# 62:	learn: 12.0275573	total: 12.4s	remaining: 17.1s
# 63:	learn: 11.9926462	total: 12.6s	remaining: 16.9s
# 64:	learn: 11.8014003	total: 12.7s	remaining: 16.7s
# 65:	learn: 11.7791185	total: 12.9s	remaining: 16.4s
# 66:	learn: 11.7474931	total: 13.1s	remaining: 16.2s
# 67:	learn: 11.7167259	total: 13.3s	remaining: 16s
# 68:	learn: 11.6955270	total: 13.5s	remaining: 15.9s
# 69:	learn: 11.6829434	total: 13.7s	remaining: 15.6s
# 70:	learn: 11.5331306	total: 13.9s	remaining: 15.4s
# 71:	learn: 11.5061075	total: 14s	remaining: 15.2s
# 72:	learn: 11.4795534	total: 14.2s	remaining: 15s
# 73:	learn: 11.4572331	total: 14.4s	remaining: 14.8s
# 74:	learn: 11.3901152	total: 14.6s	remaining: 14.6s
# 75:	learn: 11.3682271	total: 14.8s	remaining: 14.4s
# 76:	learn: 11.3404499	total: 15s	remaining: 14.2s
# 77:	learn: 11.3197075	total: 15.1s	remaining: 14s
# 78:	learn: 11.2937608	total: 15.3s	remaining: 13.8s
# 79:	learn: 11.2786645	total: 15.5s	remaining: 13.6s
# 80:	learn: 11.2566676	total: 15.7s	remaining: 13.3s
# 81:	learn: 11.2274678	total: 15.8s	remaining: 13.1s
# 82:	learn: 11.2040958	total: 16.1s	remaining: 13s
# 83:	learn: 11.1806987	total: 16.2s	remaining: 12.8s
# 84:	learn: 11.0560400	total: 16.4s	remaining: 12.6s
# 85:	learn: 11.0362451	total: 16.6s	remaining: 12.4s
# 86:	learn: 11.0106080	total: 16.8s	remaining: 12.2s
# 87:	learn: 10.9943503	total: 17s	remaining: 12s
# 88:	learn: 10.9733141	total: 17.2s	remaining: 11.8s
# 89:	learn: 10.9588284	total: 17.3s	remaining: 11.6s
# 90:	learn: 10.9325359	total: 17.5s	remaining: 11.4s
# 91:	learn: 10.9208433	total: 17.7s	remaining: 11.2s
# 92:	learn: 10.9079481	total: 17.9s	remaining: 11s
# 93:	learn: 10.8867902	total: 18.1s	remaining: 10.8s
# 94:	learn: 10.8682909	total: 18.3s	remaining: 10.6s
# 95:	learn: 10.8299887	total: 18.4s	remaining: 10.4s
# 96:	learn: 10.7762108	total: 18.6s	remaining: 10.2s
# 97:	learn: 10.7545989	total: 18.8s	remaining: 9.97s
# 98:	learn: 10.7406892	total: 19s	remaining: 9.77s
# 99:	learn: 10.7096381	total: 19.1s	remaining: 9.57s
# 100:	learn: 10.6942066	total: 19.3s	remaining: 9.37s
# 101:	learn: 10.6680667	total: 19.5s	remaining: 9.17s
# 102:	learn: 10.6567004	total: 19.7s	remaining: 8.98s
# 103:	learn: 10.6421076	total: 19.9s	remaining: 8.78s
# 104:	learn: 10.6212066	total: 20s	remaining: 8.59s
# 105:	learn: 10.5268891	total: 20.2s	remaining: 8.39s
# 106:	learn: 10.4952655	total: 20.4s	remaining: 8.19s
# 107:	learn: 10.4774140	total: 20.6s	remaining: 8s
# 108:	learn: 10.4611647	total: 20.8s	remaining: 7.8s
# 109:	learn: 10.4525046	total: 20.9s	remaining: 7.61s
# 110:	learn: 10.4396308	total: 21.1s	remaining: 7.41s
# 111:	learn: 10.4304509	total: 21.3s	remaining: 7.22s
# 112:	learn: 10.4202890	total: 21.5s	remaining: 7.03s
# 113:	learn: 10.3964864	total: 21.6s	remaining: 6.83s
# 114:	learn: 10.3702588	total: 21.8s	remaining: 6.64s
# 115:	learn: 10.3560273	total: 22s	remaining: 6.45s
# 116:	learn: 10.3350857	total: 22.2s	remaining: 6.25s
# 117:	learn: 10.3232978	total: 22.4s	remaining: 6.06s
# 118:	learn: 10.2982348	total: 22.5s	remaining: 5.87s
# 119:	learn: 10.2671176	total: 22.7s	remaining: 5.68s
# 120:	learn: 10.2490089	total: 22.9s	remaining: 5.49s
# 121:	learn: 10.2378061	total: 23.1s	remaining: 5.29s
# 122:	learn: 10.2238908	total: 23.2s	remaining: 5.1s
# 123:	learn: 10.2058219	total: 23.4s	remaining: 4.91s
# 124:	learn: 10.1969677	total: 23.6s	remaining: 4.72s
# 125:	learn: 10.1741703	total: 23.8s	remaining: 4.53s
# 126:	learn: 10.1641723	total: 24s	remaining: 4.34s
# 127:	learn: 10.1533942	total: 24.1s	remaining: 4.15s
# 128:	learn: 10.1394263	total: 24.3s	remaining: 3.96s
# 129:	learn: 10.1255983	total: 24.5s	remaining: 3.77s
# 130:	learn: 10.1061260	total: 24.7s	remaining: 3.58s
# 131:	learn: 10.0893874	total: 24.8s	remaining: 3.39s
# 132:	learn: 10.0614972	total: 25s	remaining: 3.2s
# 133:	learn: 10.0280632	total: 25.2s	remaining: 3.01s
# 134:	learn: 10.0066578	total: 25.4s	remaining: 2.82s
# 135:	learn: 9.9908721	total: 25.6s	remaining: 2.63s
# 136:	learn: 9.9789836	total: 25.8s	remaining: 2.44s
# 137:	learn: 9.9689846	total: 25.9s	remaining: 2.26s
# 138:	learn: 9.9585544	total: 26.1s	remaining: 2.07s
# 139:	learn: 9.9436278	total: 26.3s	remaining: 1.88s
# 140:	learn: 9.9300539	total: 26.5s	remaining: 1.69s
# 141:	learn: 9.9233442	total: 26.7s	remaining: 1.5s
# 142:	learn: 9.9060890	total: 26.8s	remaining: 1.31s
# 143:	learn: 9.8961016	total: 27s	remaining: 1.13s
# 144:	learn: 9.8872165	total: 27.2s	remaining: 938ms
# 145:	learn: 9.8644883	total: 27.4s	remaining: 750ms
# 146:	learn: 9.8536733	total: 27.6s	remaining: 563ms
# 147:	learn: 9.8416360	total: 27.8s	remaining: 375ms
# 148:	learn: 9.8323056	total: 28s	remaining: 188ms
# 149:	learn: 9.8200306	total: 28.1s	remaining: 0us

# %%
pred = np.array(test_preds).mean(axis=0) * 1.2

# %%
test = pd.read_csv('test_dataset_test.csv', sep=';', dtype={'VISIT_MONTH_YEAR': str})
test['PATIENT_ID_COUNT'] = pred.clip(min=1).round().astype(int)

# %%
test['PATIENT_ID_COUNT']
# Out:
# 0        3
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 39368    2
# 39369    2
# 39370    2
# 39371    2
# 39372    2
# Name: PATIENT_ID_COUNT, Length: 39373, dtype: int64

# %%
test.to_csv('submission.csv', sep=';', index=False)

# %%
list(zip(model.feature_names_, model.feature_importances_))
# Out:
# [('PATIENT_SEX', 0.07991665126733129),
#  ('MKB_CODE', 2.7520095169641596),
#  ('ADRES', 0.4728776938850512),
#  ('AGE_CATEGORY', 1.3407099381705967),
#  ('MONTH', 2.1077550641560188),
#  ('CODE_TYPE', 0.4908465108969259),
#  ('CODE_CATEGORY', 0.6805861988469861),
#  ('size', 1.4808584728274818),
#  ('DAY', 0.0),
#  ('PATIENT_ID_COUNT_prev_month', 60.162200147288615),
#  ('PATIENT_ID_COUNT_prev_year', 6.706338347920101),
#  ('PATIENT_ID_COUNT_prev_2_month', 2.9130260575293105),
#  ('PATIENT_ID_COUNT_prev_11_month', 2.187346639544919),
#  ('PATIENT_ID_COUNT_prev_13_month', 3.505136624768918),
#  ('PATIENT_ID_COUNT_prev_month_size', 5.773624448408061),
#  ('PATIENT_ID_COUNT_prev_year_size', 0.1206114168695087),
#  ('PATIENT_ID_COUNT_prev_2_month_size', 0.14970380058718077),
#  ('PATIENT_ID_COUNT_prev_11_month_size', 0.3600057535370258),
#  ('PATIENT_ID_COUNT_prev_13_month_size', 0.10354525155020981),
#  ('PATIENT_ID_COUNT_prev_month_code_type', 2.6611391828622),
#  ('PATIENT_ID_COUNT_prev_year_code_type', 0.6527224923785729),
#  ('PATIENT_ID_COUNT_prev_2_month_code_type', 1.6058978046661727),
#  ('PATIENT_ID_COUNT_prev_11_month_code_type', 2.2360230133751307),
#  ('PATIENT_ID_COUNT_prev_13_month_code_type', 0.8688717440464045),
#  ('PATIENT_ID_COUNT_prev_month_code_category', 0.24832101687005628),
#  ('PATIENT_ID_COUNT_prev_year_code_category', 0.019543800853565357),
#  ('PATIENT_ID_COUNT_prev_2_month_code_category', 0.10648015993641703),
#  ('PATIENT_ID_COUNT_prev_11_month_code_category', 0.03074510429917146),
#  ('PATIENT_ID_COUNT_prev_13_month_code_category', 0.18315714569389724)]
